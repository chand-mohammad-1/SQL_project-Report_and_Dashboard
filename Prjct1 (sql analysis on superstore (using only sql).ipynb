# %%
# !pip install ipython-sql psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\hp\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: psycopg2 in c:\users\hp\anaconda3\lib\site-packages (2.9.7)
# Requirement already satisfied: prettytable in c:\users\hp\anaconda3\lib\site-packages (from ipython-sql) (3.9.0)
# Requirement already satisfied: ipython in c:\users\hp\anaconda3\lib\site-packages (from ipython-sql) (8.12.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipython-sql) (2.0.20)
# Requirement already satisfied: sqlparse in c:\users\hp\anaconda3\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\hp\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.6.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\hp\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (2.0.1)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:12345@localhost:5432/sql_analysis

# %%
# %%sql select * from store
# limit 1
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [('CA-2011-103800           ', datetime.date(2013, 1, 3), datetime.date(2013, 1, 7), 'Standard Class', 'DP-13000                 ', 'Darren Powers', 'Consumer', 'United States', 'Houston', 'Texas', 77095, 'Central', 'OFF-PA-10000174', 'Office Supplies', 'Paper', 'Message Book, Wirebound, Four 5 1/2 X 4 Forms/Pg., 200 Dupl. Sets/Book', 16.448, 2, 0.2, 5.5512, 3.2896, 2013, 'old customer', 'Not Returned', 'Not Returned')]

# %%
######################################################################

# %%
##########################################################################################3

# %% [markdown]
# # BASIC LEVEL ANALYSIS

# %%
#Database Size

# %sql SELECT pg_size_pretty(pg_database_size('sql_analysis'));
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [('11 MB',)]

# %%
#Table Size

# %sql SELECT pg_size_pretty(pg_relation_size('store'));
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [('3456 kB',)]

# %%
#row count of data 
# %sql SELECT COUNT(*) AS Row_Count FROM store
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(9989,)]

# %%
#column count of data

# %%
# %%sql SELECT COUNT(*) AS column_Count FROM information_schema.columns
#
# WHERE table_name = 'store'
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(26,)]

# %%
#Check Dataset Information

# %%
# %%sql SELECT *
# FROM INFORMATION_SCHEMA.COLUMNS
# WHERE table_name = 'store'
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 26 rows affected.
# [('sql_analysis', 'public', 'store', 'order_date', 3, None, 'YES', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'date', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'sales', 18, None, 'YES', 'double precision', None, None, 53, 2, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'float8', None, None, None, None, '18', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'quantity', 19, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'int4', None, None, None, None, '19', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'discount', 20, None, 'YES', 'double precision', None, None, 53, 2, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'float8', None, None, None, None, '20', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'profit', 21, None, 'YES', 'double precision', None, None, 53, 2, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'float8', None, None, None, None, '21', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'discount_amount', 22, None, 'YES', 'double precision', None, None, 53, 2, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'float8', None, None, None, None, '22', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'years', 23, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'int4', None, None, None, None, '23', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'postal_code', 12, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'int4', None, None, None, None, '12', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'ship_date', 4, None, 'YES', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'date', None, None, None, None, '4', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'row_id', 1, "nextval('store_row_id_seq'::regclass)", 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'int4', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'product_id', 14, None, 'YES', 'character varying', 75, 300, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '14', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'category', 15, None, 'YES', 'character varying', 25, 100, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '15', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'sub_category', 16, None, 'YES', 'character varying', 25, 100, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '16', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'product_name', 17, None, 'YES', 'character varying', 255, 1020, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '17', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'customer_duration', 24, None, 'YES', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '24', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'returned_items', 25, None, 'YES', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '25', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'return_reason', 26, None, 'YES', 'character varying', 255, 1020, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '26', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'order_id', 2, None, 'YES', 'character', 25, 100, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'bpchar', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'ship_mode', 5, None, 'YES', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '5', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'customer_id', 6, None, 'YES', 'character', 25, 100, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'bpchar', None, None, None, None, '6', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'customer_name', 7, None, 'YES', 'character varying', 75, 300, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '7', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'segment', 8, None, 'YES', 'character varying', 25, 100, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '8', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'country', 9, None, 'YES', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '9', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'city', 10, None, 'YES', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '10', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'states', 11, None, 'YES', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '11', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('sql_analysis', 'public', 'store', 'region', 13, None, 'YES', 'character varying', 12, 48, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'sql_analysis', 'pg_catalog', 'varchar', None, None, None, None, '13', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES')]

# %%
#get column names of store data

# %%
# %%sql select column_name
# from INFORMATION_SCHEMA.COLUMNS
# where TABLE_NAME='store'
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 26 rows affected.
# [('order_date',),
#  ('sales',),
#  ('quantity',),
#  ('discount',),
#  ('profit',),
#  ('discount_amount',),
#  ('years',),
#  ('postal_code',),
#  ('ship_date',),
#  ('row_id',),
#  ('product_id',),
#  ('category',),
#  ('sub_category',),
#  ('product_name',),
#  ('customer_duration',),
#  ('returned_items',),
#  ('return_reason',),
#  ('order_id',),
#  ('ship_mode',),
#  ('customer_id',),
#  ('customer_name',),
#  ('segment',),
#  ('country',),
#  ('city',),
#  ('states',),
#  ('region',)]

# %%
#get column names with data type of store data

# %%
# %%sql select column_name,data_type
# from INFORMATION_SCHEMA.COLUMNS
# where TABLE_NAME='store'
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 26 rows affected.
# [('order_date', 'date'),
#  ('sales', 'double precision'),
#  ('quantity', 'integer'),
#  ('discount', 'double precision'),
#  ('profit', 'double precision'),
#  ('discount_amount', 'double precision'),
#  ('years', 'integer'),
#  ('postal_code', 'integer'),
#  ('ship_date', 'date'),
#  ('row_id', 'integer'),
#  ('product_id', 'character varying'),
#  ('category', 'character varying'),
#  ('sub_category', 'character varying'),
#  ('product_name', 'character varying'),
#  ('customer_duration', 'character varying'),
#  ('returned_items', 'character varying'),
#  ('return_reason', 'character varying'),
#  ('order_id', 'character'),
#  ('ship_mode', 'character varying'),
#  ('customer_id', 'character'),
#  ('customer_name', 'character varying'),
#  ('segment', 'character varying'),
#  ('country', 'character varying'),
#  ('city', 'character varying'),
#  ('states', 'character varying'),
#  ('region', 'character varying')]

# %%
# checking null values of store data

# %%
# %%sql SELECT * FROM store
# WHERE (select column_name
# from INFORMATION_SCHEMA.COLUMNS
# where TABLE_NAME='store') IS NULL;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# (psycopg2.errors.CardinalityViolation) more than one row returned by a subquery used as an expression
#
# [SQL: SELECT * FROM store
# WHERE (select column_name
# from INFORMATION_SCHEMA.COLUMNS
# where TABLE_NAME='store') IS NULL;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql SELECT *
# FROM store
# WHERE order_date IS NULL OR
# sales IS NULL OR
# quantity IS NULL OR
# discount IS NULL OR
# profit IS NULL OR
# discount_amount IS NULL OR
# years IS NULL OR
# postal_code IS NULL OR
# ship_date IS NULL OR
# row_id IS NULL OR
# product_id IS NULL OR
# category IS NULL OR
# sub_category IS NULL OR
# product_name IS NULL OR
# customer_duration IS NULL OR
# returned_items IS NULL OR
# return_reason IS NULL OR
# order_id IS NULL OR
# ship_mode IS NULL OR
# customer_id IS NULL OR
# customer_name IS NULL OR
# segment IS NULL OR
# country IS NULL OR
# city IS NULL OR
# states IS NULL OR
# region IS NULL
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 0 rows affected.
# []

# %%
#Dropping Unnecessary column like Row_ID

# %%
# %sql ALTER TABLE "store" DROP COLUMN "row_id";
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# Done.
# []

# %%
# %sql select * from store limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('CA-2011-103800           ', datetime.date(2013, 1, 3), datetime.date(2013, 1, 7), 'Standard Class', 'DP-13000                 ', 'Darren Powers', 'Consumer', 'United States', 'Houston', 'Texas', 77095, 'Central', 'OFF-PA-10000174', 'Office Supplies', 'Paper', 'Message Book, Wirebound, Four 5 1/2 X 4 Forms/Pg., 200 Dupl. Sets/Book', 16.448, 2, 0.2, 5.5512, 3.2896, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-LA-10003223', 'Office Supplies', 'Labels', 'Avery 508', 11.784, 3, 0.2, 4.2717, 2.3568, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-ST-10002743', 'Office Supplies', 'Storage', 'SAFCO Boltless Steel Shelving', 272.736, 3, 0.2, -64.7748, 54.5472, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-BI-10004094', 'Office Supplies', 'Binders', 'GBC Standard Plastic Binding Systems Combs', 3.54, 2, 0.8, -5.487, 2.832, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-141817           ', datetime.date(2013, 1, 5), datetime.date(2013, 1, 12), 'Standard Class', 'MB-18085                 ', 'Mick Brown', 'Consumer', 'United States', 'Philadelphia', 'Pennsylvania', 19143, 'East', 'OFF-AR-10003478', 'Office Supplies', 'Art', 'Avery Hi-Liter EverBold Pen Style Fluorescent Highlighters, 4/Pack', 19.536, 3, 0.2, 4.884, 3.9072, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-130813           ', datetime.date(2013, 1, 6), datetime.date(2013, 1, 8), 'Second Class', 'LS-17230                 ', 'Lycoris Saunders', 'Consumer', 'United States', 'Los Angeles', 'California', 90049, 'West', 'OFF-PA-10002005', 'Office Supplies', 'Paper', 'Xerox 225', 19.44, 3, 0.0, 9.3312, 0.0, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-106054           ', datetime.date(2013, 1, 6), datetime.date(2013, 1, 7), 'First Class', 'JO-15145                 ', "Jack O'Briant", 'Corporate', 'United States', 'Athens', 'Georgia', 30605, 'South', 'OFF-AR-10002399', 'Office Supplies', 'Art', 'Dixon Prang Watercolor Pencils, 10-Color Set with Brush', 12.78, 3, 0.0, 5.2398, 0.0, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-167199           ', datetime.date(2013, 1, 6), datetime.date(2013, 1, 10), 'Standard Class', 'ME-17320                 ', 'Maria Etezadi', 'Home Office', 'United States', 'Henderson', 'Kentucky', 42420, 'South', 'FUR-CH-10004063', 'Furniture', 'Chairs', "Global Deluxe High-Back Manager's Chair", 2573.82, 9, 0.0, 746.4078, 0.0, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-167199           ', datetime.date(2013, 1, 6), datetime.date(2013, 1, 10), 'Standard Class', 'ME-17320                 ', 'Maria Etezadi', 'Home Office', 'United States', 'Henderson', 'Kentucky', 42420, 'South', 'OFF-BI-10004632', 'Office Supplies', 'Binders', 'Ibico Hi-Tech Manual Binding System', 609.98, 2, 0.0, 274.491, 0.0, 2013, 'old customer', 'Not Returned', 'Not Returned'),
#  ('CA-2011-167199           ', datetime.date(2013, 1, 6), datetime.date(2013, 1, 10), 'Standard Class', 'ME-17320                 ', 'Maria Etezadi', 'Home Office', 'United States', 'Henderson', 'Kentucky', 42420, 'South', 'OFF-AR-10001662', 'Office Supplies', 'Art', 'Rogers Handheld Barrel Pencil Sharpener', 5.48, 2, 0.0, 1.4796, 0.0, 2013, 'old customer', 'Not Returned', 'Not Returned')]

# %%
#Check the count of United States

# %%
# %%sql select count(*) AS US_Count
# from store
# where country = 'United States'
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(9989,)]

# %%
#This row isn't important for modeling purposes, but important for auto-generating latitude and longitude on Tableau. So, We won't drop it.

# %% [markdown]
# # PRODUCT LEVEL ANALYSIS

# %%
#What are the unique product categories?

# %%
# %sql select distinct (Category) from store
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 3 rows affected.
# [('Furniture',), ('Office Supplies',), ('Technology',)]

# %%
#What is the number of products in each category?

# %%
# %%sql SELECT Category, count(*) AS No_of_Products
# FROM store
# GROUP BY Category
# order by  count(*) desc
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 3 rows affected.
# [('Office Supplies', 6021), ('Furniture', 2121), ('Technology', 1847)]

# %%
#Find the number of Subcategories products that are divided.

# %%
# %%sql select count(distinct (Sub_Category)) As No_of_Sub_Categories
# from store
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(17,)]

# %%
#Find the number of products in each sub-category.

# %%
# %%sql SELECT Sub_Category, count(*) As No_of_products
# FROM store
# GROUP BY Sub_Category
# order by  count(*) desc
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 17 rows affected.
# [('Binders', 1522),
#  ('Paper', 1370),
#  ('Furnishings', 957),
#  ('Phones', 889),
#  ('Storage', 846),
#  ('Art', 796),
#  ('Accessories', 775),
#  ('Chairs', 617),
#  ('Appliances', 462),
#  ('Labels', 364),
#  ('Tables', 319),
#  ('Envelopes', 254),
#  ('Bookcases', 228),
#  ('Fasteners', 217),
#  ('Supplies', 190),
#  ('Machines', 115),
#  ('Copiers', 68)]

# %%
#Find the number of unique product names.

# %%
# %%sql select count(distinct (Product_Name)) As No_of_unique_products
# from store
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(1849,)]

# %%
#Which are the Top 10 Products that are ordered frequently?

# %%
# %%sql SELECT Product_Name, count(*) AS No_of_products
# FROM store
# GROUP BY Product_Name
# order by  count(*) desc
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('Staple envelope', 48),
#  ('Easy-staple paper', 46),
#  ('Staples', 46),
#  ('Avery Non-Stick Binders', 20),
#  ('Staples in misc. colors', 19),
#  ('Staple remover', 18),
#  ('KI Adjustable-Height Table', 18),
#  ('Storex Dura Pro Binders', 17),
#  ('Staple-based wall hangings', 16),
#  ('Logitech 910-002974 M325 Wireless Mouse for Web Scrolling', 15)]

# %%
#Calculate the cost for each Order_Id with respective Product Name.

# %%
# %%sql select Order_Id,Product_Name,ROUND(CAST((sales-profit) AS NUMERIC), 2)as cost
# from store
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('CA-2011-103800           ', 'Message Book, Wirebound, Four 5 1/2 X 4 Forms/Pg., 200 Dupl. Sets/Book', Decimal('10.90')),
#  ('CA-2011-112326           ', 'Avery 508', Decimal('7.51')),
#  ('CA-2011-112326           ', 'SAFCO Boltless Steel Shelving', Decimal('337.51')),
#  ('CA-2011-112326           ', 'GBC Standard Plastic Binding Systems Combs', Decimal('9.03')),
#  ('CA-2011-141817           ', 'Avery Hi-Liter EverBold Pen Style Fluorescent Highlighters, 4/Pack', Decimal('14.65')),
#  ('CA-2011-130813           ', 'Xerox 225', Decimal('10.11')),
#  ('CA-2011-106054           ', 'Dixon Prang Watercolor Pencils, 10-Color Set with Brush', Decimal('7.54')),
#  ('CA-2011-167199           ', "Global Deluxe High-Back Manager's Chair", Decimal('1827.41')),
#  ('CA-2011-167199           ', 'Ibico Hi-Tech Manual Binding System', Decimal('335.49')),
#  ('CA-2011-167199           ', 'Rogers Handheld Barrel Pencil Sharpener', Decimal('4.00'))]

# %%
#Calculate % profit for each Order_ID with respective Product Name.

# %%
# %%sql select Order_Id,Product_Name,ROUND(CAST((profit/((sales-profit))*100)AS NUMERIC),2) as percentage_profit
# from store
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('CA-2011-103800           ', 'Message Book, Wirebound, Four 5 1/2 X 4 Forms/Pg., 200 Dupl. Sets/Book', Decimal('50.94')),
#  ('CA-2011-112326           ', 'Avery 508', Decimal('56.86')),
#  ('CA-2011-112326           ', 'SAFCO Boltless Steel Shelving', Decimal('-19.19')),
#  ('CA-2011-112326           ', 'GBC Standard Plastic Binding Systems Combs', Decimal('-60.78')),
#  ('CA-2011-141817           ', 'Avery Hi-Liter EverBold Pen Style Fluorescent Highlighters, 4/Pack', Decimal('33.33')),
#  ('CA-2011-130813           ', 'Xerox 225', Decimal('92.31')),
#  ('CA-2011-106054           ', 'Dixon Prang Watercolor Pencils, 10-Color Set with Brush', Decimal('69.49')),
#  ('CA-2011-167199           ', "Global Deluxe High-Back Manager's Chair", Decimal('40.85')),
#  ('CA-2011-167199           ', 'Ibico Hi-Tech Manual Binding System', Decimal('81.82')),
#  ('CA-2011-167199           ', 'Rogers Handheld Barrel Pencil Sharpener', Decimal('36.99'))]

# %% [markdown]
# #Calculate percentage profit and group by them with Product Name and Order_Id.
# #Introducing method using WITH

# %%
# %%sql WITH store_new as(
# select a.*,b.percentage_profit
# from store as a
# left join
# (select ((profit/((sales-profit))*100)) as percentage_profit,order_id,Product_Name from store
# group by percentage_profit,Product_Name,order_id) as b
# on a.order_id=b.order_id)
# select * from store_new
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('CA-2011-103800           ', datetime.date(2013, 1, 3), datetime.date(2013, 1, 7), 'Standard Class', 'DP-13000                 ', 'Darren Powers', 'Consumer', 'United States', 'Houston', 'Texas', 77095, 'Central', 'OFF-PA-10000174', 'Office Supplies', 'Paper', 'Message Book, Wirebound, Four 5 1/2 X 4 Forms/Pg., 200 Dupl. Sets/Book', 16.448, 2, 0.2, 5.5512, 3.2896, 2013, 'old customer', 'Not Returned', 'Not Returned', 50.94339622641508),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-LA-10003223', 'Office Supplies', 'Labels', 'Avery 508', 11.784, 3, 0.2, 4.2717, 2.3568, 2013, 'old customer', 'Not Returned', 'Not Returned', 56.86274509803921),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-LA-10003223', 'Office Supplies', 'Labels', 'Avery 508', 11.784, 3, 0.2, 4.2717, 2.3568, 2013, 'old customer', 'Not Returned', 'Not Returned', -60.78431372549019),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-LA-10003223', 'Office Supplies', 'Labels', 'Avery 508', 11.784, 3, 0.2, 4.2717, 2.3568, 2013, 'old customer', 'Not Returned', 'Not Returned', -19.19191919191919),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-ST-10002743', 'Office Supplies', 'Storage', 'SAFCO Boltless Steel Shelving', 272.736, 3, 0.2, -64.7748, 54.5472, 2013, 'old customer', 'Not Returned', 'Not Returned', 56.86274509803921),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-ST-10002743', 'Office Supplies', 'Storage', 'SAFCO Boltless Steel Shelving', 272.736, 3, 0.2, -64.7748, 54.5472, 2013, 'old customer', 'Not Returned', 'Not Returned', -60.78431372549019),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-ST-10002743', 'Office Supplies', 'Storage', 'SAFCO Boltless Steel Shelving', 272.736, 3, 0.2, -64.7748, 54.5472, 2013, 'old customer', 'Not Returned', 'Not Returned', -19.19191919191919),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-BI-10004094', 'Office Supplies', 'Binders', 'GBC Standard Plastic Binding Systems Combs', 3.54, 2, 0.8, -5.487, 2.832, 2013, 'old customer', 'Not Returned', 'Not Returned', 56.86274509803921),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-BI-10004094', 'Office Supplies', 'Binders', 'GBC Standard Plastic Binding Systems Combs', 3.54, 2, 0.8, -5.487, 2.832, 2013, 'old customer', 'Not Returned', 'Not Returned', -60.78431372549019),
#  ('CA-2011-112326           ', datetime.date(2013, 1, 4), datetime.date(2013, 1, 8), 'Standard Class', 'PO-19195                 ', 'Phillina Ober', 'Home Office', 'United States', 'Naperville', 'Illinois', 60540, 'Central', 'OFF-BI-10004094', 'Office Supplies', 'Binders', 'GBC Standard Plastic Binding Systems Combs', 3.54, 2, 0.8, -5.487, 2.832, 2013, 'old customer', 'Not Returned', 'Not Returned', -19.19191919191919)]

# %%
#Same Thing Using normal method without creating any temporary data. Here, This can be only viewed for one time and we can't merge with the current dataset in this process.

# %%
# %%sql select  product_id,order_id,((profit/((sales-profit))*100)) as percentage_profit
# from store
# group by product_id,order_id,percentage_profit
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('OFF-BI-10002609', 'US-2013-110156           ', -62.962962962962976),
#  ('OFF-AR-10002257', 'CA-2011-101427           ', 15.942028985507248),
#  ('TEC-PH-10000455', 'CA-2011-124688           ', 40.8450704225352),
#  ('FUR-CH-10003199', 'US-2013-134488           ', -7.894736842105263),
#  ('OFF-PA-10001947', 'CA-2012-163104           ', 96.078431372549),
#  ('OFF-AR-10003478', 'CA-2011-155208           ', 33.33333333333333),
#  ('FUR-CH-10003774', 'US-2013-127971           ', -19.54022988505747),
#  ('TEC-AC-10004396', 'CA-2012-146675           ', -10.112359550561797),
#  ('FUR-CH-10004754', 'CA-2013-118899           ', 9.589041095890412),
#  ('OFF-ST-10001590', 'US-2012-159982           ', 8.108108108108107)]

# %% [markdown]
# /* Where can we trim some loses?
#    In Which products?
#    We can do this by calculating the average sales and profits, and comparing the values to that average.
#    If the sales or profits are below average, then they are not best sellers and
#    can be analyzed deeper to see if its worth selling thema anymore. */

# %%
# %%sql SELECT round(cast(AVG(sales) as numeric),2) AS avg_sales
# FROM store;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(Decimal('229.83'),)]

# %% [markdown]
# #the average sales on any given product is 229.8, so approx. 230.

# %%
# %%sql SELECT round(cast(AVG(Profit)as numeric),2) AS avg_profit
# FROM store;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(Decimal('28.65'),)]

# %% [markdown]
# -- the average profit on any given product is 28.6, or approx 29.

# %%
#Average sales per sub-cat

# %%
# %%sql SELECT round(cast(AVG(sales) as numeric),2) AS avg_sales, Sub_Category
# FROM store
# GROUP BY Sub_Category
# ORDER BY avg_sales asc
# limit 9;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 9 rows affected.
# [(Decimal('13.94'), 'Fasteners'),
#  (Decimal('34.07'), 'Art'),
#  (Decimal('34.30'), 'Labels'),
#  (Decimal('57.28'), 'Paper'),
#  (Decimal('64.87'), 'Envelopes'),
#  (Decimal('95.83'), 'Furnishings'),
#  (Decimal('133.64'), 'Binders'),
#  (Decimal('215.97'), 'Accessories'),
#  (Decimal('229.77'), 'Appliances')]

# %% [markdown]
# --The sales of these Sub_category products are below the average sales.

# %%
#Average profit per sub-cat

# %%
# %%sql SELECT round(cast(AVG(Profit)as numeric),2) AS avg_prof,Sub_Category
# FROM store
# GROUP BY Sub_Category
# ORDER BY avg_prof asc
# limit 11;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 11 rows affected.
# [(Decimal('-55.57'), 'Tables'),
#  (Decimal('-15.23'), 'Bookcases'),
#  (Decimal('-6.26'), 'Supplies'),
#  (Decimal('4.38'), 'Fasteners'),
#  (Decimal('8.20'), 'Art'),
#  (Decimal('13.65'), 'Furnishings'),
#  (Decimal('15.24'), 'Labels'),
#  (Decimal('19.85'), 'Binders'),
#  (Decimal('24.86'), 'Paper'),
#  (Decimal('25.15'), 'Storage'),
#  (Decimal('27.42'), 'Envelopes')]

# %% [markdown]
# --The profit of these Sub_category products are below the average profit.
# -- "Minus sign" Respresnts that those products are in losses.

# %% [markdown]
# # CUSTOMER LEVEL ANALYSIS

# %%
#What is the number of unique customer IDs?

# %%
# %%sql select count(distinct (Customer_id)) as no_of_unique_custd_ID
# from store
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(793,)]

# %%
#Find those customers who registered during 2014-2016.

# %%
# %%sql select distinct  (Customer_ID), Order_ID,city, Postal_Code
# from store
# where Customer_Id is not null
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('NP-18685                 ', 'CA-2012-141768           ', 'San Francisco', 94109),
#  ('VB-21745                 ', 'CA-2014-155698           ', 'Columbus', 31907),
#  ('DH-13075                 ', 'CA-2012-159534           ', 'New York City', 10035),
#  ('MD-17860                 ', 'CA-2014-153654           ', 'Asheville', 28806),
#  ('JH-16180                 ', 'CA-2012-126739           ', 'New York City', 10035),
#  ('NZ-18565                 ', 'CA-2013-110772           ', 'Columbus', 43229),
#  ('BD-11620                 ', 'CA-2014-130211           ', 'Lawton', 73505),
#  ('BD-11320                 ', 'CA-2012-121699           ', 'Detroit', 48227),
#  ('SP-20920                 ', 'CA-2013-105291           ', 'San Luis Obispo', 93405),
#  ('NP-18670                 ', 'CA-2014-150091           ', 'Lakewood', 8701)]

# %%
#Calculate Total Frequency of each order id by each customer Name in descending order.

# %%
# %%sql select order_id, customer_id, count(Order_Id) as total_order_id
# from store
# group by order_id,customer_id
# order by total_order_id desc
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('CA-2014-100111           ', 'SV-20365                 ', 14),
#  ('CA-2014-157987           ', 'AC-10615                 ', 12),
#  ('CA-2013-165330           ', 'WB-21850                 ', 11),
#  ('US-2013-108504           ', 'PP-18955                 ', 11),
#  ('US-2012-126977           ', 'PF-19120                 ', 10),
#  ('CA-2013-105732           ', 'AG-10270                 ', 10),
#  ('CA-2012-131338           ', 'NP-18325                 ', 10),
#  ('CA-2011-106439           ', 'GG-14650                 ', 9),
#  ('CA-2012-164882           ', 'SG-20080                 ', 9),
#  ('US-2012-163433           ', 'MP-17965                 ', 9)]

# %%
#Calculate  cost of each customer name.

# %%
# %%sql select order_id, customer_id, City, Quantity,sales,(sales-profit) as costs,profit
# from store
# group by order_id,customer_id,City,Quantity,Costs,sales,profit
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('CA-2014-121293           ', 'JC-15775                 ', 'Philadelphia', 4, 20.736, 13.4784, 7.2576),
#  ('CA-2011-127866           ', 'JD-15895                 ', 'Riverside', 4, 13.12, 9.315199999999999, 3.8048),
#  ('US-2012-126753           ', 'SP-20860                 ', 'Philadelphia', 4, 519.792, 632.4136000000001, -112.6216),
#  ('CA-2014-143112           ', 'TS-21370                 ', 'New York City', 4, 87.8, 43.9, 43.9),
#  ('CA-2013-161907           ', 'JH-16180                 ', 'Philadelphia', 4, 769.184, 932.6356, -163.4516),
#  ('CA-2014-113355           ', 'SJ-20215                 ', 'Grand Prairie', 3, 317.058, 335.1756, -18.1176),
#  ('CA-2013-123274           ', 'GT-14710                 ', 'New York City', 3, 242.94, 233.2224, 9.7176),
#  ('CA-2012-167010           ', 'VT-21700                 ', 'Philadelphia', 4, 10.428, 17.380000000000003, -6.952),
#  ('CA-2014-127432           ', 'AD-10180                 ', 'Great Falls', 3, 1126.02, 1069.719, 56.301),
#  ('CA-2012-159534           ', 'DH-13075                 ', 'New York City', 2, 199.98, 145.9854, 53.9946)]

# %%
#Display No of Customers in each region in descending order.

# %%
# %%sql select Region, count(*) as No_of_Customers
# from store
# group by region
# order by no_of_customers desc
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 4 rows affected.
# [('West', 3202), ('East', 2847), ('Central', 2321), ('South', 1619)]

# %%
#Find Top 10 customers who order frequently.

# %%
# %%sql SELECT Customer_Name, count(*) as no_of_order
# FROM store
# GROUP BY Customer_Name
# order by  count(*) desc
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('William Brown', 37),
#  ('Paul Prost', 34),
#  ('Matt Abelman', 34),
#  ('John Lee', 34),
#  ('Chloris Kastensmidt', 32),
#  ('Seth Vernon', 32),
#  ('Jonathan Doherty', 32),
#  ('Edward Hooks', 32),
#  ('Zuschuss Carroll', 31),
#  ('Arthur Prichep', 31)]

# %%
#Find Top 20 Customers who benefitted the store.

# %%
# %%sql SELECT Customer_Name, Profit, City, States
# FROM store
# GROUP BY Customer_Name,Profit,City,States
# order by  Profit desc
# limit 20
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 20 rows affected.
# [('Tamara Chand', 8399.976, 'Lafayette', 'Indiana'),
#  ('Raymond Buch', 6719.9808, 'Seattle', 'Washington'),
#  ('Hunter Lopez', 5039.9856, 'Newark', 'Delaware'),
#  ('Adrian Barton', 4946.37, 'Detroit', 'Michigan'),
#  ('Sanjit Chand', 4630.4755, 'Minneapolis', 'Minnesota'),
#  ('Tom Ashbrook', 3919.9888, 'New York City', 'New York'),
#  ('Christopher Martinez', 3177.475, 'Atlanta', 'Georgia'),
#  ('Sanjit Engle', 2799.984, 'Arlington', 'Virginia'),
#  ('Daniel Raglin', 2591.9568, 'Providence', 'Rhode Island'),
#  ('Andy Reiter', 2504.2216, 'Jackson', 'Michigan'),
#  ('Karen Daniels', 2400.9657, 'Yonkers', 'New York'),
#  ('Bill Shonely', 2365.9818, 'Lakewood', 'New Jersey'),
#  ('Harry Marie', 2302.9671, 'Springfield', 'Missouri'),
#  ('Tom Boeckenhauer', 2239.9872, 'New York City', 'New York'),
#  ('Keith Dawkins', 2229.024, 'New York City', 'New York'),
#  ('Nathan Mautz', 1995.99, 'New York City', 'New York'),
#  ('Jane Waco', 1906.485, 'Sacramento', 'California'),
#  ('Shirley Daniels', 1906.485, 'Midland', 'Michigan'),
#  ('Steven Roelle', 1668.205, 'New York City', 'New York'),
#  ('Dennis Pardue', 1644.2913, 'North Las Vegas', 'Nevada')]

# %%
#Which state(s) is the superstore most succesful in? Least?
#Top 10 results:

# %%
# %%sql SELECT round(cast(SUM(sales) as numeric),2) AS state_sales, States
# FROM Store
# GROUP BY States
# ORDER BY state_sales DESC
# OFFSET 1 ROWS FETCH NEXT 10 ROWS ONLY;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [(Decimal('310876.27'), 'New York'),
#  (Decimal('170188.05'), 'Texas'),
#  (Decimal('138641.27'), 'Washington'),
#  (Decimal('116511.91'), 'Pennsylvania'),
#  (Decimal('89086.57'), 'Florida'),
#  (Decimal('80166.10'), 'Illinois'),
#  (Decimal('77871.00'), 'Ohio'),
#  (Decimal('76269.61'), 'Michigan'),
#  (Decimal('70636.72'), 'Virginia'),
#  (Decimal('55603.16'), 'North Carolina')]

# %% [markdown]
# # ORDER LEVEL ANALYSIS

# %%
#number of unique orders

# %%
# %%sql select count(distinct (Order_ID)) as no_of_unique_orders
# from store
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(5007,)]

# %%
#Find Sum Total Sales of Superstore.

# %%
# %%sql select round(cast(SUM(sales) as numeric),2) as Total_Sales
# from store
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(Decimal('2295810.15'),)]

# %%
#Calculate the time taken for an order to ship and converting the no. of days in int format.

# %%
# %%sql select order_id,customer_id,customer_name,city,states, (ship_date-order_date) as delivery_duration
# from store
# order by delivery_duration desc
# limit 20
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 20 rows affected.
# [('CA-2011-148586           ', 'AZ-10750                 ', 'Annie Zypern', 'New York City', 'New York', 7),
#  ('CA-2011-147298           ', 'AG-10300                 ', 'Aleksandra Gannaway', 'Los Angeles', 'California', 7),
#  ('CA-2011-118339           ', 'BN-11515                 ', 'Bradley Nguyen', 'Lakeville', 'Minnesota', 7),
#  ('CA-2011-118339           ', 'BN-11515                 ', 'Bradley Nguyen', 'Lakeville', 'Minnesota', 7),
#  ('CA-2011-110555           ', 'MM-18055                 ', 'Michelle Moray', 'Great Falls', 'Montana', 7),
#  ('CA-2011-147298           ', 'AG-10300                 ', 'Aleksandra Gannaway', 'Los Angeles', 'California', 7),
#  ('CA-2011-154165           ', 'DL-13315                 ', 'Delfina Latchford', 'Chicago', 'Illinois', 7),
#  ('CA-2011-118339           ', 'BN-11515                 ', 'Bradley Nguyen', 'Lakeville', 'Minnesota', 7),
#  ('CA-2011-118339           ', 'BN-11515                 ', 'Bradley Nguyen', 'Lakeville', 'Minnesota', 7),
#  ('CA-2011-118339           ', 'BN-11515                 ', 'Bradley Nguyen', 'Lakeville', 'Minnesota', 7),
#  ('CA-2011-100363           ', 'JM-15655                 ', 'Jim Mitchum', 'Glendale', 'Arizona', 7),
#  ('CA-2011-100363           ', 'JM-15655                 ', 'Jim Mitchum', 'Glendale', 'Arizona', 7),
#  ('CA-2011-110555           ', 'MM-18055                 ', 'Michelle Moray', 'Great Falls', 'Montana', 7),
#  ('CA-2011-110555           ', 'MM-18055                 ', 'Michelle Moray', 'Great Falls', 'Montana', 7),
#  ('CA-2011-123400           ', 'EB-13930                 ', 'Eric Barreto', 'Saint Petersburg', 'Florida', 7),
#  ('CA-2011-123400           ', 'EB-13930                 ', 'Eric Barreto', 'Saint Petersburg', 'Florida', 7),
#  ('US-2011-140116           ', 'KT-16480                 ', 'Kean Thornton', 'Denver', 'Colorado', 7),
#  ('US-2011-140116           ', 'KT-16480                 ', 'Kean Thornton', 'Denver', 'Colorado', 7),
#  ('CA-2011-141817           ', 'MB-18085                 ', 'Mick Brown', 'Philadelphia', 'Pennsylvania', 7),
#  ('CA-2011-135755           ', 'NC-18415                 ', 'Nathan Cano', 'Yonkers', 'New York', 7)]

# %%
#Extract the year  for respective order ID and Customer ID with quantity.

# %%
# %%sql select order_id,customer_id,quantity,EXTRACT(YEAR from Order_Date)
# from store
# group by order_id,customer_id,quantity,EXTRACT(YEAR from Order_Date)
# order by quantity desc
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 8614 rows affected.
# [('CA-2011-154165           ', 'DL-13315                 ', 14, Decimal('2013')),
#  ('CA-2012-120621           ', 'JW-16075                 ', 14, Decimal('2014')),
#  ('CA-2011-158337           ', 'KA-16525                 ', 14, Decimal('2013')),
#  ('CA-2014-123491           ', 'JK-15205                 ', 14, Decimal('2016')),
#  ('US-2013-103674           ', 'AP-10720                 ', 14, Decimal('2015')),
#  ('CA-2013-105732           ', 'AG-10270                 ', 14, Decimal('2015')),
#  ('CA-2014-130036           ', 'BP-11185                 ', 14, Decimal('2016')),
#  ('CA-2012-103135           ', 'SS-20515                 ', 14, Decimal('2014')),
#  ('CA-2011-120768           ', 'IM-15070                 ', 14, Decimal('2013')),
#  ('CA-2014-169859           ', 'MP-18175                 ', 14, Decimal('2016')),
#  ('CA-2014-161410           ', 'CC-12220                 ', 14, Decimal('2016')),
#  ('CA-2011-115259           ', 'RC-19960                 ', 14, Decimal('2013')),
#  ('CA-2013-116596           ', 'BW-11200                 ', 14, Decimal('2015')),
#  ('US-2012-119312           ', 'CS-12400                 ', 14, Decimal('2014')),
#  ('CA-2013-141887           ', 'MP-17470                 ', 14, Decimal('2015')),
#  ('CA-2013-140571           ', 'SJ-20125                 ', 14, Decimal('2015')),
#  ('CA-2011-154599           ', 'KN-16450                 ', 14, Decimal('2013')),
#  ('CA-2012-146563           ', 'CB-12025                 ', 14, Decimal('2014')),
#  ('US-2014-155425           ', 'AB-10600                 ', 14, Decimal('2016')),
#  ('CA-2014-151750           ', 'JM-15250                 ', 14, Decimal('2016')),
#  ('US-2012-164448           ', 'DK-12835                 ', 14, Decimal('2014')),
#  ('CA-2011-163447           ', 'TB-21190                 ', 14, Decimal('2013')),
#  ('CA-2012-149713           ', 'TG-21640                 ', 14, Decimal('2014')),
#  ('CA-2014-164028           ', 'JL-15835                 ', 14, Decimal('2016')),
#  ('CA-2013-142405           ', 'SE-20110                 ', 14, Decimal('2015')),
#  ('CA-2012-104241           ', 'AG-10495                 ', 14, Decimal('2014')),
#  ('CA-2013-145583           ', 'LC-16885                 ', 14, Decimal('2015')),
#  ('CA-2014-152702           ', 'SN-20710                 ', 14, Decimal('2016')),
#  ('CA-2012-135489           ', 'GW-14605                 ', 14, Decimal('2014')),
#  ('US-2011-151015           ', 'BD-11500                 ', 13, Decimal('2013')),
#  ('CA-2014-132234           ', 'MY-17380                 ', 13, Decimal('2016')),
#  ('CA-2013-117121           ', 'AB-10105                 ', 13, Decimal('2015')),
#  ('CA-2012-116638           ', 'JH-15985                 ', 13, Decimal('2014')),
#  ('CA-2014-117457           ', 'KH-16510                 ', 13, Decimal('2016')),
#  ('CA-2014-147942           ', 'MS-17365                 ', 13, Decimal('2016')),
#  ('US-2014-147669           ', 'SV-20935                 ', 13, Decimal('2016')),
#  ('CA-2011-134215           ', 'ML-17395                 ', 13, Decimal('2013')),
#  ('CA-2012-148712           ', 'JM-15535                 ', 13, Decimal('2014')),
#  ('CA-2014-129378           ', 'NS-18505                 ', 13, Decimal('2016')),
#  ('US-2011-155502           ', 'SD-20485                 ', 13, Decimal('2013')),
#  ('CA-2011-101364           ', 'TW-21025                 ', 13, Decimal('2013')),
#  ('US-2012-126214           ', 'JS-15880                 ', 13, Decimal('2014')),
#  ('CA-2011-114321           ', 'NC-18535                 ', 13, Decimal('2013')),
#  ('CA-2014-114524           ', 'EG-13900                 ', 13, Decimal('2016')),
#  ('US-2013-165505           ', 'CB-12535                 ', 13, Decimal('2015')),
#  ('CA-2011-106439           ', 'GG-14650                 ', 13, Decimal('2013')),
#  ('CA-2014-129021           ', 'PO-18850                 ', 13, Decimal('2016')),
#  ('CA-2012-138898           ', 'JH-16180                 ', 13, Decimal('2014')),
#  ('CA-2011-153927           ', 'LL-16840                 ', 13, Decimal('2013')),
#  ('CA-2011-122336           ', 'JD-15895                 ', 13, Decimal('2013')),
#  ('CA-2013-145625           ', 'KC-16540                 ', 13, Decimal('2015')),
#  ('CA-2013-162390           ', 'DP-13105                 ', 13, Decimal('2015')),
#  ('CA-2012-129525           ', 'VP-21760                 ', 13, Decimal('2014')),
#  ('CA-2013-138695           ', 'KC-16675                 ', 13, Decimal('2015')),
#  ('CA-2014-115602           ', 'DJ-13630                 ', 13, Decimal('2016')),
#  ('CA-2011-116190           ', 'SG-20470                 ', 13, Decimal('2013')),
#  ('CA-2012-109470           ', 'KC-16255                 ', 12, Decimal('2014')),
#  ('CA-2011-122336           ', 'JD-15895                 ', 12, Decimal('2013')),
#  ('CA-2014-113530           ', 'BC-11125                 ', 12, Decimal('2016')),
#  ('CA-2014-146535           ', 'FM-14290                 ', 12, Decimal('2016')),
#  ('CA-2013-147123           ', 'SJ-20125                 ', 12, Decimal('2015')),
#  ('CA-2011-168494           ', 'NP-18700                 ', 12, Decimal('2013')),
#  ('CA-2014-115364           ', 'OT-18730                 ', 12, Decimal('2016')),
#  ('CA-2014-112431           ', 'RW-19690                 ', 12, Decimal('2016')),
#  ('US-2014-105998           ', 'CR-12580                 ', 12, Decimal('2016')),
#  ('US-2013-110156           ', 'EH-13945                 ', 12, Decimal('2015')),
#  ('CA-2013-104150           ', 'AG-10330                 ', 12, Decimal('2015')),
#  ('CA-2013-145492           ', 'MC-17605                 ', 12, Decimal('2015')),
#  ('US-2014-110576           ', 'RB-19795                 ', 12, Decimal('2016')),
#  ('CA-2011-139192           ', 'LC-16885                 ', 12, Decimal('2013')),
#  ('CA-2013-109365           ', 'XP-21865                 ', 12, Decimal('2015')),
#  ('CA-2014-101805           ', 'SH-19975                 ', 12, Decimal('2016')),
#  ('CA-2011-102673           ', 'KH-16630                 ', 12, Decimal('2013')),
#  ('CA-2012-125976           ', 'JK-15205                 ', 12, Decimal('2014')),
#  ('CA-2012-122168           ', 'HG-14965                 ', 12, Decimal('2014')),
#  ('CA-2011-114510           ', 'JF-15295                 ', 12, Decimal('2013')),
#  ('US-2013-119046           ', 'EH-13765                 ', 12, Decimal('2015')),
#  ('CA-2013-139808           ', 'MC-18100                 ', 12, Decimal('2015')),
#  ('CA-2012-137925           ', 'JL-15235                 ', 12, Decimal('2014')),
#  ('US-2011-160444           ', 'DC-12850                 ', 11, Decimal('2013')),
#  ('CA-2012-160227           ', 'ED-13885                 ', 11, Decimal('2014')),
#  ('CA-2011-116834           ', 'Dp-13240                 ', 11, Decimal('2013')),
#  ('CA-2011-115049           ', 'MM-17920                 ', 11, Decimal('2013')),
#  ('CA-2011-164469           ', 'GK-14620                 ', 11, Decimal('2013')),
#  ('US-2014-142188           ', 'JF-15415                 ', 11, Decimal('2016')),
#  ('CA-2012-135622           ', 'TT-21460                 ', 11, Decimal('2014')),
#  ('CA-2014-128965           ', 'PS-18760                 ', 11, Decimal('2016')),
#  ('CA-2014-122490           ', 'TT-21070                 ', 11, Decimal('2016')),
#  ('CA-2014-113418           ', 'CM-12655                 ', 11, Decimal('2016')),
#  ('CA-2014-126074           ', 'RF-19735                 ', 11, Decimal('2016')),
#  ('CA-2013-116722           ', 'LP-17080                 ', 11, Decimal('2015')),
#  ('CA-2014-100111           ', 'SV-20365                 ', 11, Decimal('2016')),
#  ('CA-2014-160899           ', 'DR-12940                 ', 11, Decimal('2016')),
#  ('US-2014-123862           ', 'JF-15190                 ', 11, Decimal('2016')),
#  ('CA-2011-158470           ', 'AG-10390                 ', 11, Decimal('2013')),
#  ('CA-2012-107902           ', 'SM-20950                 ', 11, Decimal('2014')),
#  ('CA-2011-154669           ', 'TM-21010                 ', 11, Decimal('2013')),
#  ('CA-2012-108259           ', 'NS-18640                 ', 11, Decimal('2014')),
#  ('CA-2011-142314           ', 'SF-20200                 ', 11, Decimal('2013')),
#  ('CA-2011-122931           ', 'SM-20950                 ', 11, Decimal('2013')),
#  ('CA-2014-123372           ', 'DG-13300                 ', 11, Decimal('2016')),
#  ('CA-2014-144498           ', 'MB-18085                 ', 11, Decimal('2016')),
#  ('US-2013-124163           ', 'SC-20695                 ', 11, Decimal('2015')),
#  ('CA-2013-114489           ', 'JE-16165                 ', 11, Decimal('2015')),
#  ('CA-2014-139913           ', 'JC-16105                 ', 11, Decimal('2016')),
#  ('CA-2012-166975           ', 'SH-20635                 ', 11, Decimal('2014')),
#  ('CA-2012-164441           ', 'AC-10450                 ', 11, Decimal('2014')),
#  ('CA-2012-135853           ', 'CA-12775                 ', 11, Decimal('2014')),
#  ('CA-2014-144463           ', 'SC-20725                 ', 11, Decimal('2016')),
#  ('CA-2012-151470           ', 'AM-10705                 ', 11, Decimal('2014')),
#  ('US-2011-150126           ', 'AS-10045                 ', 11, Decimal('2013')),
#  ('CA-2014-137414           ', 'CM-12115                 ', 11, Decimal('2016')),
#  ('US-2012-107944           ', 'AM-10360                 ', 11, Decimal('2014')),
#  ('CA-2012-153381           ', 'DE-13255                 ', 10, Decimal('2014')),
#  ('CA-2011-120670           ', 'JK-16120                 ', 10, Decimal('2013')),
#  ('CA-2013-162236           ', 'ER-13855                 ', 10, Decimal('2015')),
#  ('CA-2011-146591           ', 'TS-21340                 ', 10, Decimal('2013')),
#  ('CA-2013-167507           ', 'SA-20830                 ', 10, Decimal('2015')),
#  ('CA-2011-117464           ', 'NP-18325                 ', 10, Decimal('2013')),
#  ('CA-2012-137708           ', 'NG-18430                 ', 10, Decimal('2014')),
#  ('CA-2011-125612           ', 'BK-11260                 ', 10, Decimal('2013')),
#  ('CA-2011-129364           ', 'TB-21250                 ', 10, Decimal('2013')),
#  ('CA-2013-107202           ', 'LC-16930                 ', 10, Decimal('2015')),
#  ('CA-2011-124429           ', 'MH-17785                 ', 10, Decimal('2013')),
#  ('CA-2011-118339           ', 'BN-11515                 ', 10, Decimal('2013')),
#  ('CA-2014-138611           ', 'CK-12595                 ', 10, Decimal('2016')),
#  ('CA-2014-146724           ', 'HG-15025                 ', 10, Decimal('2016')),
#  ('CA-2014-150420           ', 'GD-14590                 ', 10, Decimal('2016')),
#  ('CA-2011-128209           ', 'GT-14710                 ', 10, Decimal('2013')),
#  ('CA-2011-131947           ', 'JA-15970                 ', 10, Decimal('2013')),
#  ('US-2014-133200           ', 'DB-13555                 ', 10, Decimal('2016')),
#  ('CA-2013-132661           ', 'SR-20740                 ', 10, Decimal('2015')),
#  ('CA-2012-150714           ', 'KH-16690                 ', 10, Decimal('2014')),
#  ('US-2013-141544           ', 'PO-18850                 ', 10, Decimal('2015')),
#  ('US-2012-118766           ', 'LS-16975                 ', 10, Decimal('2014')),
#  ('CA-2011-125556           ', 'ML-17410                 ', 10, Decimal('2013')),
#  ('CA-2013-164770           ', 'MY-18295                 ', 10, Decimal('2015')),
#  ('CA-2013-147109           ', 'AH-10075                 ', 10, Decimal('2015')),
#  ('US-2012-163685           ', 'KE-16420                 ', 10, Decimal('2014')),
#  ('CA-2014-142391           ', 'PB-19150                 ', 10, Decimal('2016')),
#  ('CA-2013-167983           ', 'RP-19270                 ', 10, Decimal('2015')),
#  ('CA-2012-100251           ', 'DV-13465                 ', 10, Decimal('2014')),
#  ('US-2014-116652           ', 'RD-19480                 ', 10, Decimal('2016')),
#  ('CA-2014-131492           ', 'HH-15010                 ', 10, Decimal('2016')),
#  ('CA-2014-155621           ', 'KN-16450                 ', 10, Decimal('2016')),
#  ('CA-2012-140718           ', 'FA-14230                 ', 10, Decimal('2014')),
#  ('CA-2012-162047           ', 'FH-14365                 ', 10, Decimal('2014')),
#  ('US-2014-129777           ', 'FM-14290                 ', 10, Decimal('2016')),
#  ('CA-2014-117023           ', 'JW-15955                 ', 10, Decimal('2016')),
#  ('US-2014-165344           ', 'SB-20290                 ', 10, Decimal('2016')),
#  ('CA-2012-138331           ', 'JK-15625                 ', 10, Decimal('2014')),
#  ('CA-2011-132801           ', 'JG-15805                 ', 10, Decimal('2013')),
#  ('CA-2011-111871           ', 'EK-13795                 ', 10, Decimal('2013')),
#  ('CA-2014-116953           ', 'SV-20935                 ', 10, Decimal('2016')),
#  ('CA-2014-117667           ', 'MS-17980                 ', 10, Decimal('2016')),
#  ('CA-2014-111332           ', 'NC-18340                 ', 10, Decimal('2016')),
#  ('CA-2013-146325           ', 'DS-13180                 ', 10, Decimal('2015')),
#  ('CA-2013-102561           ', 'NK-18490                 ', 10, Decimal('2015')),
#  ('CA-2014-118213           ', 'AB-10060                 ', 10, Decimal('2016')),
#  ('US-2011-119137           ', 'AG-10900                 ', 10, Decimal('2013')),
#  ('CA-2011-122336           ', 'JD-15895                 ', 10, Decimal('2013')),
#  ('CA-2012-163181           ', 'AB-10105                 ', 10, Decimal('2014')),
#  ('CA-2013-113831           ', 'AH-10690                 ', 10, Decimal('2015')),
#  ('CA-2014-104136           ', 'SF-20065                 ', 10, Decimal('2016')),
#  ('CA-2014-108574           ', 'MG-18145                 ', 10, Decimal('2016')),
#  ('CA-2014-167227           ', 'NP-18670                 ', 10, Decimal('2016')),
#  ('CA-2012-162201           ', 'AG-10495                 ', 10, Decimal('2014')),
#  ('US-2012-115238           ', 'JW-15220                 ', 10, Decimal('2014')),
#  ('US-2012-166520           ', 'KE-16420                 ', 10, Decimal('2014')),
#  ('CA-2011-151897           ', 'VT-21700                 ', 10, Decimal('2013')),
#  ('CA-2013-116232           ', 'AC-10450                 ', 9, Decimal('2015')),
#  ('CA-2014-100223           ', 'LS-16945                 ', 9, Decimal('2016')),
#  ('CA-2013-157161           ', 'JD-15895                 ', 9, Decimal('2015')),
#  ('CA-2014-128944           ', 'KH-16330                 ', 9, Decimal('2016')),
#  ('CA-2013-103730           ', 'SC-20725                 ', 9, Decimal('2015')),
#  ('CA-2012-165624           ', 'FH-14350                 ', 9, Decimal('2014')),
#  ('US-2014-119039           ', 'BF-11170                 ', 9, Decimal('2016')),
#  ('CA-2014-135860           ', 'JH-15985                 ', 9, Decimal('2016')),
#  ('US-2014-117534           ', 'CV-12295                 ', 9, Decimal('2016')),
#  ('CA-2012-142202           ', 'JR-16210                 ', 9, Decimal('2014')),
#  ('CA-2013-101791           ', 'BS-11665                 ', 9, Decimal('2015')),
#  ('US-2014-166037           ', 'CL-12700                 ', 9, Decimal('2016')),
#  ('CA-2012-110016           ', 'BT-11395                 ', 9, Decimal('2014')),
#  ('CA-2011-106439           ', 'GG-14650                 ', 9, Decimal('2013')),
#  ('US-2013-140158           ', 'DR-12940                 ', 9, Decimal('2015')),
#  ('US-2013-126431           ', 'SU-20665                 ', 9, Decimal('2015')),
#  ('CA-2013-159940           ', 'BF-11020                 ', 9, Decimal('2015')),
#  ('CA-2013-107104           ', 'MS-17365                 ', 9, Decimal('2015')),
#  ('CA-2011-128839           ', 'TT-21070                 ', 9, Decimal('2013')),
#  ('CA-2014-163188           ', 'EC-14050                 ', 9, Decimal('2016')),
#  ('CA-2012-124800           ', 'RW-19540                 ', 9, Decimal('2014')),
#  ('CA-2013-157259           ', 'JM-15535                 ', 9, Decimal('2015')),
#  ('CA-2012-143882           ', 'DB-13360                 ', 9, Decimal('2014')),
#  ('CA-2012-136805           ', 'NM-18445                 ', 9, Decimal('2014')),
#  ('CA-2014-138975           ', 'SC-20380                 ', 9, Decimal('2016')),
#  ('CA-2012-109638           ', 'JH-15985                 ', 9, Decimal('2014')),
#  ('CA-2012-105347           ', 'DP-13000                 ', 9, Decimal('2014')),
#  ('CA-2013-120824           ', 'AW-10930                 ', 9, Decimal('2015')),
#  ('CA-2013-126809           ', 'EB-13750                 ', 9, Decimal('2015')),
#  ('CA-2014-102407           ', 'AT-10435                 ', 9, Decimal('2016')),
#  ('US-2014-109253           ', 'PR-18880                 ', 9, Decimal('2016')),
#  ('CA-2013-166380           ', 'EB-13750                 ', 9, Decimal('2015')),
#  ('CA-2014-126242           ', 'MC-18100                 ', 9, Decimal('2016')),
#  ('CA-2014-100335           ', 'NF-18595                 ', 9, Decimal('2016')),
#  ('CA-2014-102379           ', 'BB-11545                 ', 9, Decimal('2016')),
#  ('CA-2011-146731           ', 'AT-10735                 ', 9, Decimal('2013')),
#  ('CA-2013-109722           ', 'TP-21130                 ', 9, Decimal('2015')),
#  ('CA-2011-139892           ', 'BM-11140                 ', 9, Decimal('2013')),
#  ('CA-2013-158778           ', 'DB-13210                 ', 9, Decimal('2015')),
#  ('CA-2012-169572           ', 'AG-10525                 ', 9, Decimal('2014')),
#  ('CA-2012-140984           ', 'CC-12685                 ', 9, Decimal('2014')),
#  ('US-2014-103814           ', 'LH-16900                 ', 9, Decimal('2016')),
#  ('CA-2014-143574           ', 'DR-12880                 ', 9, Decimal('2016')),
#  ('CA-2012-165057           ', 'SC-20725                 ', 9, Decimal('2014')),
#  ('CA-2014-108287           ', 'AG-10330                 ', 9, Decimal('2016')),
#  ('CA-2011-124856           ', 'LD-17005                 ', 9, Decimal('2013')),
#  ('CA-2013-158694           ', 'AI-10855                 ', 9, Decimal('2015')),
#  ('CA-2014-100111           ', 'SV-20365                 ', 9, Decimal('2016')),
#  ('CA-2014-105991           ', 'LH-17020                 ', 9, Decimal('2016')),
#  ('CA-2014-118724           ', 'AR-10825                 ', 9, Decimal('2016')),
#  ('CA-2013-130946           ', 'ZC-21910                 ', 9, Decimal('2015')),
#  ('CA-2011-124807           ', 'ME-17725                 ', 9, Decimal('2013')),
#  ('CA-2012-112319           ', 'AR-10510                 ', 9, Decimal('2014')),
#  ('CA-2012-127607           ', 'JK-15730                 ', 9, Decimal('2014')),
#  ('CA-2014-144064           ', 'CP-12085                 ', 9, Decimal('2016')),
#  ('CA-2014-152786           ', 'GA-14725                 ', 9, Decimal('2016')),
#  ('US-2013-146066           ', 'RB-19465                 ', 9, Decimal('2015')),
#  ('CA-2012-157812           ', 'DB-13210                 ', 9, Decimal('2014')),
#  ('US-2014-106131           ', 'TP-21565                 ', 9, Decimal('2016')),
#  ('CA-2012-131338           ', 'NP-18325                 ', 9, Decimal('2014')),
#  ('CA-2012-121188           ', 'CB-12025                 ', 9, Decimal('2014')),
#  ('CA-2013-165330           ', 'WB-21850                 ', 9, Decimal('2015')),
#  ('US-2014-164147           ', 'DW-13585                 ', 9, Decimal('2016')),
#  ('CA-2011-165806           ', 'VM-21685                 ', 9, Decimal('2013')),
#  ('CA-2012-114069           ', 'ND-18370                 ', 9, Decimal('2014')),
#  ('CA-2012-132626           ', 'BT-11680                 ', 9, Decimal('2014')),
#  ('CA-2013-130638           ', 'SC-20095                 ', 9, Decimal('2015')),
#  ('CA-2014-135937           ', 'KM-16375                 ', 9, Decimal('2016')),
#  ('CA-2013-114209           ', 'AS-10285                 ', 9, Decimal('2015')),
#  ('CA-2014-157469           ', 'ES-14080                 ', 9, Decimal('2016')),
#  ('CA-2011-102673           ', 'KH-16630                 ', 9, Decimal('2013')),
#  ('CA-2011-159520           ', 'GT-14635                 ', 9, Decimal('2013')),
#  ('CA-2011-153969           ', 'HF-14995                 ', 9, Decimal('2013')),
#  ('CA-2014-143567           ', 'TB-21175                 ', 9, Decimal('2016')),
#  ('CA-2014-162789           ', 'LC-17140                 ', 9, Decimal('2016')),
#  ('US-2012-120131           ', 'LM-17065                 ', 9, Decimal('2014')),
#  ('CA-2013-120796           ', 'CS-11950                 ', 9, Decimal('2015')),
#  ('CA-2012-154291           ', 'YS-21880                 ', 9, Decimal('2014')),
#  ('CA-2013-145982           ', 'TB-21055                 ', 9, Decimal('2015')),
#  ('CA-2012-127173           ', 'GM-14500                 ', 9, Decimal('2014')),
#  ('CA-2014-117947           ', 'NG-18355                 ', 9, Decimal('2016')),
#  ('US-2013-158288           ', 'EH-13945                 ', 9, Decimal('2015')),
#  ('US-2013-126452           ', 'SC-20230                 ', 9, Decimal('2015')),
#  ('CA-2014-152912           ', 'BM-11650                 ', 9, Decimal('2016')),
#  ('CA-2012-116876           ', 'TT-21070                 ', 9, Decimal('2014')),
#  ('CA-2012-113173           ', 'DK-13225                 ', 9, Decimal('2014')),
#  ('CA-2011-135090           ', 'SP-20920                 ', 9, Decimal('2013')),
#  ('CA-2012-137974           ', 'LL-16840                 ', 9, Decimal('2014')),
#  ('CA-2013-123358           ', 'BT-11680                 ', 9, Decimal('2015')),
#  ('US-2014-166611           ', 'CK-12760                 ', 9, Decimal('2016')),
#  ('CA-2014-137498           ', 'LC-17050                 ', 9, Decimal('2016')),
#  ('CA-2013-145303           ', 'TP-21415                 ', 9, Decimal('2015')),
#  ('US-2013-108504           ', 'PP-18955                 ', 9, Decimal('2015')),
#  ('CA-2013-133935           ', 'JW-15220                 ', 9, Decimal('2015')),
#  ('CA-2014-119809           ', 'YS-21880                 ', 9, Decimal('2016')),
#  ('CA-2013-119025           ', 'PV-18985                 ', 9, Decimal('2015')),
#  ('CA-2011-118976           ', 'MY-18295                 ', 9, Decimal('2013')),
#  ('CA-2013-126158           ', 'SC-20095                 ', 9, Decimal('2015')),
#  ('CA-2011-148425           ', 'RF-19345                 ', 9, Decimal('2013')),
#  ('US-2014-166688           ', 'RD-19480                 ', 9, Decimal('2016')),
#  ('US-2012-127040           ', 'SG-20605                 ', 9, Decimal('2014')),
#  ('CA-2014-140326           ', 'HW-14935                 ', 9, Decimal('2016')),
#  ('CA-2013-100244           ', 'GM-14695                 ', 9, Decimal('2015')),
#  ('CA-2012-117884           ', 'DC-13285                 ', 9, Decimal('2014')),
#  ('CA-2014-137085           ', 'CT-11995                 ', 9, Decimal('2016')),
#  ('CA-2013-148684           ', 'TS-21655                 ', 9, Decimal('2015')),
#  ('CA-2011-163552           ', 'LA-16780                 ', 9, Decimal('2013')),
#  ('CA-2014-102610           ', 'CA-12265                 ', 9, Decimal('2016')),
#  ('CA-2014-165008           ', 'DO-13645                 ', 9, Decimal('2016')),
#  ('CA-2012-119690           ', 'MV-17485                 ', 9, Decimal('2014')),
#  ('CA-2013-124590           ', 'SP-20920                 ', 9, Decimal('2015')),
#  ('CA-2013-139269           ', 'JB-16045                 ', 9, Decimal('2015')),
#  ('US-2012-153500           ', 'DG-13300                 ', 9, Decimal('2014')),
#  ('CA-2012-103135           ', 'SS-20515                 ', 9, Decimal('2014')),
#  ('US-2013-113649           ', 'HA-14920                 ', 9, Decimal('2015')),
#  ('CA-2012-162621           ', 'CA-12055                 ', 9, Decimal('2014')),
#  ('CA-2012-137526           ', 'PB-19150                 ', 9, Decimal('2014')),
#  ('CA-2012-146262           ', 'VW-21775                 ', 9, Decimal('2014')),
#  ('CA-2012-125416           ', 'KC-16540                 ', 9, Decimal('2014')),
#  ('CA-2013-168354           ', 'RH-19510                 ', 9, Decimal('2015')),
#  ('US-2011-107699           ', 'JH-15820                 ', 9, Decimal('2013')),
#  ('CA-2013-154060           ', 'DL-12865                 ', 9, Decimal('2015')),
#  ('CA-2011-143385           ', 'SJ-20500                 ', 9, Decimal('2013')),
#  ('CA-2013-125738           ', 'PB-18805                 ', 9, Decimal('2015')),
#  ('CA-2012-103933           ', 'DR-12880                 ', 9, Decimal('2014')),
#  ('CA-2013-156685           ', 'SC-20230                 ', 9, Decimal('2015')),
#  ('CA-2012-103093           ', 'FO-14305                 ', 9, Decimal('2014')),
#  ('CA-2013-108616           ', 'JK-15730                 ', 9, Decimal('2015')),
#  ('CA-2014-167381           ', 'EH-14005                 ', 9, Decimal('2016')),
#  ('CA-2013-106950           ', 'JE-15715                 ', 9, Decimal('2015')),
#  ('CA-2012-104346           ', 'IM-15070                 ', 9, Decimal('2014')),
#  ('CA-2011-103219           ', 'BF-11215                 ', 9, Decimal('2013')),
#  ('CA-2013-169215           ', 'RE-19450                 ', 9, Decimal('2015')),
#  ('CA-2011-153913           ', 'KB-16585                 ', 9, Decimal('2013')),
#  ('CA-2012-141243           ', 'AH-10465                 ', 9, Decimal('2014')),
#  ('CA-2013-137848           ', 'WB-21850                 ', 9, Decimal('2015')),
#  ('CA-2014-168641           ', 'KA-16525                 ', 9, Decimal('2016')),
#  ('CA-2014-128853           ', 'JM-15250                 ', 9, Decimal('2016')),
#  ('US-2012-138121           ', 'JL-15835                 ', 9, Decimal('2014')),
#  ('CA-2014-130386           ', 'NG-18430                 ', 9, Decimal('2016')),
#  ('CA-2014-116715           ', 'VW-21775                 ', 9, Decimal('2016')),
#  ('CA-2013-132829           ', 'LA-16780                 ', 9, Decimal('2015')),
#  ('CA-2014-123967           ', 'SF-20200                 ', 9, Decimal('2016')),
#  ('CA-2014-126123           ', 'AG-10765                 ', 9, Decimal('2016')),
#  ('US-2014-161935           ', 'JL-15835                 ', 9, Decimal('2016')),
#  ('CA-2013-133725           ', 'KL-16645                 ', 9, Decimal('2015')),
#  ('CA-2012-132486           ', 'JF-15355                 ', 9, Decimal('2014')),
#  ('US-2014-157224           ', 'JB-16000                 ', 9, Decimal('2016')),
#  ('CA-2014-115651           ', 'NS-18640                 ', 9, Decimal('2016')),
#  ('CA-2013-149335           ', 'BC-11125                 ', 9, Decimal('2015')),
#  ('CA-2011-119172           ', 'HD-14785                 ', 9, Decimal('2013')),
#  ('CA-2014-166093           ', 'RW-19540                 ', 9, Decimal('2016')),
#  ('CA-2014-100384           ', 'NH-18610                 ', 9, Decimal('2016')),
#  ('CA-2014-133718           ', 'TB-21520                 ', 9, Decimal('2016')),
#  ('CA-2014-134194           ', 'GA-14725                 ', 9, Decimal('2016')),
#  ('CA-2013-118101           ', 'SN-20560                 ', 9, Decimal('2015')),
#  ('CA-2014-133641           ', 'EJ-14155                 ', 9, Decimal('2016')),
#  ('CA-2012-153073           ', 'HA-14905                 ', 9, Decimal('2014')),
#  ('CA-2013-160717           ', 'ME-17320                 ', 9, Decimal('2015')),
#  ('CA-2014-108574           ', 'MG-18145                 ', 9, Decimal('2016')),
#  ('CA-2012-126557           ', 'RL-19615                 ', 9, Decimal('2014')),
#  ('CA-2014-146031           ', 'GM-14440                 ', 9, Decimal('2016')),
#  ('US-2011-130358           ', 'DL-13330                 ', 9, Decimal('2013')),
#  ('CA-2014-112753           ', 'CC-12670                 ', 9, Decimal('2016')),
#  ('CA-2011-134215           ', 'ML-17395                 ', 9, Decimal('2013')),
#  ('US-2011-131870           ', 'NF-18595                 ', 9, Decimal('2013')),
#  ('CA-2012-138485           ', 'NP-18670                 ', 9, Decimal('2014')),
#  ('CA-2013-108882           ', 'LA-16780                 ', 9, Decimal('2015')),
#  ('CA-2011-128888           ', 'PB-19105                 ', 9, Decimal('2013')),
#  ('CA-2014-117457           ', 'KH-16510                 ', 9, Decimal('2016')),
#  ('CA-2011-140732           ', 'MA-17560                 ', 9, Decimal('2013')),
#  ('CA-2013-108875           ', 'CL-12700                 ', 9, Decimal('2015')),
#  ('CA-2013-110254           ', 'ML-17755                 ', 9, Decimal('2015')),
#  ('CA-2012-130113           ', 'AH-10030                 ', 9, Decimal('2014')),
#  ('CA-2012-135685           ', 'MP-18175                 ', 9, Decimal('2014')),
#  ('CA-2011-147900           ', 'JK-15640                 ', 9, Decimal('2013')),
#  ('CA-2014-145506           ', 'MO-17800                 ', 9, Decimal('2016')),
#  ('CA-2012-143490           ', 'NP-18325                 ', 9, Decimal('2014')),
#  ('CA-2012-138009           ', 'SF-20965                 ', 9, Decimal('2014')),
#  ('CA-2012-105571           ', 'CP-12340                 ', 9, Decimal('2014')),
#  ('CA-2011-126760           ', 'KM-16720                 ', 9, Decimal('2013')),
#  ('CA-2011-110786           ', 'AJ-10795                 ', 9, Decimal('2013')),
#  ('CA-2014-115602           ', 'DJ-13630                 ', 9, Decimal('2016')),
#  ('CA-2013-100671           ', 'CS-12490                 ', 9, Decimal('2015')),
#  ('CA-2014-143063           ', 'IL-15100                 ', 9, Decimal('2016')),
#  ('US-2014-130603           ', 'SC-20050                 ', 9, Decimal('2016')),
#  ('CA-2011-167199           ', 'ME-17320                 ', 9, Decimal('2013')),
#  ('CA-2011-124730           ', 'LS-17245                 ', 9, Decimal('2013')),
#  ('CA-2012-117415           ', 'SN-20710                 ', 9, Decimal('2014')),
#  ('CA-2013-140417           ', 'KE-16420                 ', 9, Decimal('2015')),
#  ('CA-2011-168823           ', 'MA-17560                 ', 9, Decimal('2013')),
#  ('CA-2011-126683           ', 'PP-18955                 ', 9, Decimal('2013')),
#  ('CA-2012-111038           ', 'LC-16960                 ', 9, Decimal('2014')),
#  ('US-2012-134558           ', 'PM-19135                 ', 9, Decimal('2014')),
#  ('CA-2013-101329           ', 'MM-17920                 ', 9, Decimal('2015')),
#  ('CA-2013-169838           ', 'BB-11545                 ', 9, Decimal('2015')),
#  ('CA-2014-138310           ', 'NP-18700                 ', 9, Decimal('2016')),
#  ('CA-2013-126732           ', 'LR-16915                 ', 9, Decimal('2015')),
#  ('CA-2013-144540           ', 'GH-14410                 ', 9, Decimal('2015')),
#  ('US-2012-117492           ', 'NS-18640                 ', 9, Decimal('2014')),
#  ('CA-2012-156482           ', 'IL-15100                 ', 9, Decimal('2014')),
#  ('US-2011-156559           ', 'LH-16900                 ', 9, Decimal('2013')),
#  ('CA-2014-103968           ', 'ML-17755                 ', 9, Decimal('2016')),
#  ('CA-2011-160766           ', 'DM-13015                 ', 9, Decimal('2013')),
#  ('US-2014-158505           ', 'SF-20200                 ', 9, Decimal('2016')),
#  ('CA-2012-137113           ', 'TW-21025                 ', 9, Decimal('2014')),
#  ('CA-2011-125997           ', 'MW-18220                 ', 9, Decimal('2013')),
#  ('CA-2014-154676           ', 'NZ-18565                 ', 9, Decimal('2016')),
#  ('US-2012-147242           ', 'EH-13765                 ', 9, Decimal('2014')),
#  ('CA-2013-101987           ', 'HL-15040                 ', 9, Decimal('2015')),
#  ('CA-2012-146948           ', 'MG-17890                 ', 9, Decimal('2014')),
#  ('US-2012-159982           ', 'DR-12880                 ', 9, Decimal('2014')),
#  ('CA-2013-127698           ', 'MV-18190                 ', 9, Decimal('2015')),
#  ('US-2013-132577           ', 'JE-15475                 ', 9, Decimal('2015')),
#  ('CA-2014-140053           ', 'CA-12265                 ', 9, Decimal('2016')),
#  ('CA-2013-164770           ', 'MY-18295                 ', 9, Decimal('2015')),
#  ('US-2011-105767           ', 'AR-10510                 ', 9, Decimal('2013')),
#  ('CA-2013-153661           ', 'SC-20725                 ', 9, Decimal('2015')),
#  ('US-2011-114188           ', 'RF-19345                 ', 9, Decimal('2013')),
#  ('CA-2014-121027           ', 'HW-14935                 ', 9, Decimal('2016')),
#  ('CA-2014-118360           ', 'JC-15775                 ', 9, Decimal('2016')),
#  ('CA-2014-102519           ', 'BM-11650                 ', 9, Decimal('2016')),
#  ('CA-2014-155159           ', 'DL-13315                 ', 9, Decimal('2016')),
#  ('CA-2011-133830           ', 'RL-19615                 ', 9, Decimal('2013')),
#  ('CA-2012-166947           ', 'EB-13750                 ', 9, Decimal('2014')),
#  ('CA-2014-132213           ', 'PN-18775                 ', 9, Decimal('2016')),
#  ('CA-2011-169019           ', 'LF-17185                 ', 9, Decimal('2013')),
#  ('CA-2011-110184           ', 'BF-11170                 ', 9, Decimal('2013')),
#  ('CA-2014-161655           ', 'CW-11905                 ', 9, Decimal('2016')),
#  ('CA-2014-136364           ', 'MH-17455                 ', 9, Decimal('2016')),
#  ('CA-2013-169334           ', 'GW-14605                 ', 9, Decimal('2015')),
#  ('CA-2014-128328           ', 'PO-18865                 ', 9, Decimal('2016')),
#  ('CA-2013-105263           ', 'LM-17065                 ', 9, Decimal('2015')),
#  ('CA-2011-151330           ', 'TC-21295                 ', 9, Decimal('2013')),
#  ('CA-2014-133004           ', 'AJ-10945                 ', 9, Decimal('2016')),
#  ('CA-2013-127194           ', 'BW-11110                 ', 9, Decimal('2015')),
#  ('CA-2012-101889           ', 'DB-13120                 ', 9, Decimal('2014')),
#  ('CA-2011-124737           ', 'AP-10915                 ', 9, Decimal('2013')),
#  ('CA-2012-146465           ', 'PB-18805                 ', 9, Decimal('2014')),
#  ('CA-2014-118892           ', 'TP-21415                 ', 9, Decimal('2016')),
#  ('CA-2014-144596           ', 'CD-11980                 ', 9, Decimal('2016')),
#  ('CA-2011-115812           ', 'BH-11710                 ', 9, Decimal('2013')),
#  ('CA-2012-124541           ', 'TT-21220                 ', 9, Decimal('2014')),
#  ('CA-2014-148264           ', 'LF-17185                 ', 9, Decimal('2016')),
#  ('CA-2011-143371           ', 'MD-17350                 ', 9, Decimal('2013')),
#  ('CA-2014-129357           ', 'KB-16585                 ', 9, Decimal('2016')),
#  ('CA-2014-103156           ', 'TD-20995                 ', 9, Decimal('2016')),
#  ('CA-2013-136133           ', 'HW-14935                 ', 9, Decimal('2015')),
#  ('CA-2013-130400           ', 'SJ-20125                 ', 9, Decimal('2015')),
#  ('CA-2012-111297           ', 'SC-20440                 ', 9, Decimal('2014')),
#  ('CA-2013-121223           ', 'GD-14590                 ', 9, Decimal('2015')),
#  ('US-2012-138093           ', 'KM-16225                 ', 9, Decimal('2014')),
#  ('CA-2012-151547           ', 'AH-10465                 ', 8, Decimal('2014')),
#  ('US-2013-148901           ', 'MK-17905                 ', 8, Decimal('2015')),
#  ('CA-2013-169838           ', 'BB-11545                 ', 8, Decimal('2015')),
#  ('CA-2012-161711           ', 'MC-17425                 ', 8, Decimal('2014')),
#  ('CA-2012-162761           ', 'SC-20575                 ', 8, Decimal('2014')),
#  ('CA-2012-153416           ', 'TS-21340                 ', 8, Decimal('2014')),
#  ('CA-2014-169894           ', 'MV-17485                 ', 8, Decimal('2016')),
#  ('CA-2011-130449           ', 'VP-21760                 ', 8, Decimal('2013')),
#  ('CA-2014-167752           ', 'RW-19690                 ', 8, Decimal('2016')),
#  ('CA-2014-139311           ', 'SF-20965                 ', 8, Decimal('2016')),
#  ('CA-2011-107818           ', 'MC-17275                 ', 8, Decimal('2013')),
#  ('CA-2011-140165           ', 'EH-14005                 ', 8, Decimal('2013')),
#  ('US-2011-150119           ', 'LB-16795                 ', 8, Decimal('2013')),
#  ('CA-2013-133368           ', 'AG-10675                 ', 8, Decimal('2015')),
#  ('CA-2013-160535           ', 'BP-11050                 ', 8, Decimal('2015')),
#  ('CA-2012-140025           ', 'PF-19120                 ', 8, Decimal('2014')),
#  ('CA-2014-139304           ', 'VG-21790                 ', 8, Decimal('2016')),
#  ('CA-2014-144883           ', 'BO-11350                 ', 8, Decimal('2016')),
#  ('CA-2013-149762           ', 'RD-19720                 ', 8, Decimal('2015')),
#  ('CA-2014-100748           ', 'RB-19795                 ', 8, Decimal('2016')),
#  ('CA-2014-152135           ', 'MG-17650                 ', 8, Decimal('2016')),
#  ('US-2013-131611           ', 'EP-13915                 ', 8, Decimal('2015')),
#  ('CA-2014-142622           ', 'JK-15625                 ', 8, Decimal('2016')),
#  ('CA-2014-107167           ', 'ND-18460                 ', 8, Decimal('2016')),
#  ('CA-2013-126158           ', 'SC-20095                 ', 8, Decimal('2015')),
#  ('CA-2014-140949           ', 'DB-13405                 ', 8, Decimal('2016')),
#  ('CA-2013-138695           ', 'KC-16675                 ', 8, Decimal('2015')),
#  ('CA-2011-112158           ', 'DP-13165                 ', 8, Decimal('2013')),
#  ('CA-2014-117212           ', 'BT-11530                 ', 8, Decimal('2016')),
#  ('CA-2013-169943           ', 'BN-11515                 ', 8, Decimal('2015')),
#  ('CA-2014-145884           ', 'SL-20155                 ', 8, Decimal('2016')),
#  ('CA-2013-120824           ', 'AW-10930                 ', 8, Decimal('2015')),
#  ('US-2013-101616           ', 'CY-12745                 ', 8, Decimal('2015')),
#  ('US-2011-118997           ', 'RA-19885                 ', 8, Decimal('2013')),
#  ('CA-2014-119284           ', 'TS-21205                 ', 8, Decimal('2016')),
#  ('CA-2012-149650           ', 'RD-19660                 ', 8, Decimal('2014')),
#  ('CA-2012-106565           ', 'BW-11110                 ', 8, Decimal('2014')),
#  ('CA-2014-108560           ', 'JC-15385                 ', 8, Decimal('2016')),
#  ('CA-2014-155985           ', 'BE-11335                 ', 8, Decimal('2016')),
#  ('CA-2014-163097           ', 'SF-20200                 ', 8, Decimal('2016')),
#  ('US-2014-102904           ', 'CB-12025                 ', 8, Decimal('2016')),
#  ('US-2013-147711           ', 'HF-14995                 ', 8, Decimal('2015')),
#  ('CA-2014-122770           ', 'EP-13915                 ', 8, Decimal('2016')),
#  ('CA-2011-122070           ', 'AH-10030                 ', 8, Decimal('2013')),
#  ('US-2014-126060           ', 'DW-13585                 ', 8, Decimal('2016')),
#  ('US-2014-141677           ', 'HK-14890                 ', 8, Decimal('2016')),
#  ('CA-2012-131884           ', 'DK-13375                 ', 8, Decimal('2014')),
#  ('CA-2012-120677           ', 'BD-11320                 ', 8, Decimal('2014')),
#  ('CA-2014-119004           ', 'JM-15250                 ', 8, Decimal('2016')),
#  ('CA-2014-153654           ', 'MD-17860                 ', 8, Decimal('2016')),
#  ('CA-2014-152310           ', 'DK-12895                 ', 8, Decimal('2016')),
#  ('CA-2013-109743           ', 'SH-19975                 ', 8, Decimal('2015')),
#  ('CA-2013-129728           ', 'JG-15310                 ', 8, Decimal('2015')),
#  ('CA-2012-164301           ', 'EB-13840                 ', 8, Decimal('2014')),
#  ('US-2014-102288           ', 'ZC-21910                 ', 8, Decimal('2016')),
#  ('CA-2014-128965           ', 'PS-18760                 ', 8, Decimal('2016')),
#  ('CA-2014-154410           ', 'MD-17860                 ', 8, Decimal('2016')),
#  ('CA-2012-151624           ', 'VW-21775                 ', 8, Decimal('2014')),
#  ('CA-2012-109603           ', 'EM-13825                 ', 8, Decimal('2014')),
#  ('CA-2011-110184           ', 'BF-11170                 ', 8, Decimal('2013')),
#  ('CA-2014-148929           ', 'SP-20620                 ', 8, Decimal('2016')),
#  ('CA-2014-124744           ', 'EH-14125                 ', 8, Decimal('2016')),
#  ('CA-2012-155145           ', 'KN-16450                 ', 8, Decimal('2014')),
#  ('CA-2012-139780           ', 'AH-10690                 ', 8, Decimal('2014')),
#  ('CA-2013-128818           ', 'CJ-12010                 ', 8, Decimal('2015')),
#  ('CA-2013-159940           ', 'BF-11020                 ', 8, Decimal('2015')),
#  ('US-2012-128090           ', 'JM-15865                 ', 8, Decimal('2014')),
#  ('CA-2013-159891           ', 'BF-11170                 ', 8, Decimal('2015')),
#  ('CA-2011-107398           ', 'BS-11590                 ', 8, Decimal('2013')),
#  ('CA-2014-149160           ', 'JM-15265                 ', 8, Decimal('2016')),
#  ('CA-2011-108609           ', 'AJ-10780                 ', 8, Decimal('2013')),
#  ('CA-2012-158421           ', 'GB-14575                 ', 8, Decimal('2014')),
#  ('CA-2013-136322           ', 'AP-10720                 ', 8, Decimal('2015')),
#  ('CA-2014-108322           ', 'SS-20140                 ', 8, Decimal('2016')),
#  ('CA-2014-122105           ', 'CJ-12010                 ', 8, Decimal('2016')),
#  ('US-2013-163881           ', 'SP-20860                 ', 8, Decimal('2015')),
#  ('CA-2014-156951           ', 'EB-13840                 ', 8, Decimal('2016')),
#  ('CA-2014-144036           ', 'FO-14305                 ', 8, Decimal('2016')),
#  ('CA-2014-143665           ', 'PO-19180                 ', 8, Decimal('2016')),
#  ('US-2011-127978           ', 'JS-15595                 ', 8, Decimal('2013')),
#  ('CA-2014-112900           ', 'KL-16645                 ', 8, Decimal('2016')),
#  ('US-2011-112914           ', 'MT-18070                 ', 8, Decimal('2013')),
#  ('CA-2013-104689           ', 'FH-14365                 ', 8, Decimal('2015')),
#  ('CA-2012-102281           ', 'MP-17470                 ', 8, Decimal('2014')),
#  ('CA-2013-149503           ', 'SP-20650                 ', 8, Decimal('2015')),
#  ('CA-2013-102162           ', 'JF-15565                 ', 8, Decimal('2015')),
#  ('CA-2011-111451           ', 'KL-16555                 ', 8, Decimal('2013')),
#  ('US-2013-125402           ', 'DL-12865                 ', 8, Decimal('2015')),
#  ('CA-2014-137022           ', 'SW-20275                 ', 8, Decimal('2016')),
#  ('CA-2013-137337           ', 'GB-14575                 ', 8, Decimal('2015')),
#  ('CA-2012-144806           ', 'GH-14425                 ', 8, Decimal('2014')),
#  ('CA-2013-130484           ', 'SG-20470                 ', 8, Decimal('2015')),
#  ('CA-2013-137673           ', 'ML-17395                 ', 8, Decimal('2015')),
#  ('CA-2013-167556           ', 'JM-15250                 ', 8, Decimal('2015')),
#  ('CA-2013-105354           ', 'PW-19030                 ', 8, Decimal('2015')),
#  ('CA-2014-130043           ', 'BB-11545                 ', 8, Decimal('2016')),
#  ('US-2011-155502           ', 'SD-20485                 ', 8, Decimal('2013')),
#  ('CA-2013-110772           ', 'NZ-18565                 ', 8, Decimal('2015')),
#  ('CA-2014-100524           ', 'CM-12115                 ', 8, Decimal('2016')),
#  ('US-2013-150861           ', 'EG-13900                 ', 8, Decimal('2015')),
#  ('CA-2013-102561           ', 'NK-18490                 ', 8, Decimal('2015')),
#  ('CA-2013-104157           ', 'MT-17815                 ', 8, Decimal('2015')),
#  ('CA-2014-101245           ', 'LW-16990                 ', 8, Decimal('2016')),
#  ('CA-2011-106376           ', 'BS-11590                 ', 8, Decimal('2013')),
#  ('US-2013-160528           ', 'MH-18115                 ', 8, Decimal('2015')),
#  ('CA-2014-122700           ', 'LT-17110                 ', 8, Decimal('2016')),
#  ('CA-2014-124261           ', 'JE-15715                 ', 8, Decimal('2016')),
#  ('CA-2013-163328           ', 'TP-21565                 ', 8, Decimal('2015')),
#  ('US-2012-145436           ', 'VD-21670                 ', 8, Decimal('2014')),
#  ('CA-2012-130848           ', 'DG-13300                 ', 8, Decimal('2014')),
#  ('CA-2014-121559           ', 'HW-14935                 ', 8, Decimal('2016')),
#  ('CA-2011-123260           ', 'FM-14290                 ', 8, Decimal('2013')),
#  ('CA-2013-149195           ', 'DM-13525                 ', 8, Decimal('2015')),
#  ('CA-2014-146626           ', 'BP-11185                 ', 8, Decimal('2016')),
#  ('CA-2011-131450           ', 'LR-16915                 ', 8, Decimal('2013')),
#  ('CA-2011-133809           ', 'MS-17530                 ', 8, Decimal('2013')),
#  ('CA-2014-155698           ', 'VB-21745                 ', 8, Decimal('2016')),
#  ('CA-2014-111738           ', 'CM-12385                 ', 8, Decimal('2016')),
#  ('CA-2014-164756           ', 'SS-20140                 ', 8, Decimal('2016')),
#  ('CA-2014-149559           ', 'KF-16285                 ', 8, Decimal('2016')),
#  ('CA-2013-127243           ', 'DS-13180                 ', 8, Decimal('2015')),
#  ('CA-2013-149111           ', 'BF-11170                 ', 8, Decimal('2015')),
#  ('US-2011-163797           ', 'PC-19000                 ', 8, Decimal('2013')),
#  ('CA-2014-127621           ', 'RE-19450                 ', 8, Decimal('2016')),
#  ('CA-2011-120474           ', 'RP-19390                 ', 8, Decimal('2013')),
#  ('US-2011-119137           ', 'AG-10900                 ', 8, Decimal('2013')),
#  ('CA-2014-166695           ', 'CC-12430                 ', 8, Decimal('2016')),
#  ('CA-2014-167941           ', 'JF-15565                 ', 8, Decimal('2016')),
#  ('CA-2012-154284           ', 'SZ-20035                 ', 8, Decimal('2014')),
#  ('US-2013-164945           ', 'CA-12055                 ', 8, Decimal('2015')),
#  ('CA-2013-145919           ', 'HG-14965                 ', 8, Decimal('2015')),
#  ('CA-2011-110527           ', 'ED-13885                 ', 8, Decimal('2013')),
#  ('CA-2013-107104           ', 'MS-17365                 ', 8, Decimal('2015')),
#  ('CA-2012-123113           ', 'AT-10735                 ', 8, Decimal('2014')),
#  ('CA-2014-157987           ', 'AC-10615                 ', 8, Decimal('2016')),
#  ('CA-2013-133711           ', 'MC-17425                 ', 8, Decimal('2015')),
#  ('CA-2013-140564           ', 'TC-21475                 ', 8, Decimal('2015')),
#  ('CA-2013-133669           ', 'SV-20935                 ', 8, Decimal('2015')),
#  ('CA-2012-102855           ', 'JF-15415                 ', 8, Decimal('2014')),
#  ('CA-2013-134803           ', 'CL-12565                 ', 8, Decimal('2015')),
#  ('US-2012-154389           ', 'EH-14125                 ', 8, Decimal('2014')),
#  ('CA-2012-124450           ', 'GT-14710                 ', 8, Decimal('2014')),
#  ('CA-2011-104780           ', 'BT-11530                 ', 8, Decimal('2013')),
#  ('US-2014-141852           ', 'JE-15745                 ', 8, Decimal('2016')),
#  ('CA-2013-158841           ', 'SE-20110                 ', 8, Decimal('2015')),
#  ('CA-2014-160983           ', 'GB-14530                 ', 8, Decimal('2016')),
#  ('CA-2014-107797           ', 'EB-13705                 ', 8, Decimal('2016')),
#  ('CA-2011-136644           ', 'SC-20575                 ', 8, Decimal('2013')),
#  ('CA-2012-145849           ', 'CT-11995                 ', 8, Decimal('2014')),
#  ('CA-2012-153038           ', 'RB-19645                 ', 8, Decimal('2014')),
#  ('CA-2014-132178           ', 'DB-12970                 ', 8, Decimal('2016')),
#  ('CA-2014-105991           ', 'LH-17020                 ', 8, Decimal('2016')),
#  ('CA-2013-114860           ', 'DN-13690                 ', 8, Decimal('2015')),
#  ('CA-2013-111318           ', 'IL-15100                 ', 8, Decimal('2015')),
#  ('CA-2013-103709           ', 'LP-17095                 ', 8, Decimal('2015')),
#  ('CA-2014-156237           ', 'PS-18760                 ', 8, Decimal('2016')),
#  ('US-2014-139465           ', 'MR-17545                 ', 8, Decimal('2016')),
#  ('CA-2014-139717           ', 'DM-13015                 ', 8, Decimal('2016')),
#  ('US-2013-103646           ', 'SP-20545                 ', 8, Decimal('2015')),
#  ('CA-2012-114468           ', 'TD-20995                 ', 8, Decimal('2014')),
#  ('US-2013-146570           ', 'SN-20710                 ', 8, Decimal('2015')),
#  ('CA-2011-121664           ', 'HP-14815                 ', 8, Decimal('2013')),
#  ('US-2012-168914           ', 'JE-15745                 ', 8, Decimal('2014')),
#  ('CA-2013-121671           ', 'AA-10480                 ', 8, Decimal('2015')),
#  ('CA-2013-146423           ', 'BT-11680                 ', 8, Decimal('2015')),
#  ('CA-2012-109190           ', 'CC-12685                 ', 8, Decimal('2014')),
#  ('CA-2013-114307           ', 'MF-17665                 ', 8, Decimal('2015')),
# ...
#  ('CA-2013-139934           ', 'AY-10555                 ', 7, Decimal('2015')),
#  ('CA-2014-153080           ', 'EH-13945                 ', 7, Decimal('2016')),
#  ('CA-2013-116799           ', 'JG-15310                 ', 7, Decimal('2015')),
#  ('CA-2012-115798           ', 'KL-16645                 ', 7, Decimal('2014')),
#  ('CA-2014-122693           ', 'NH-18610                 ', 7, Decimal('2016')),
#  ('CA-2013-130267           ', 'SW-20245                 ', 7, Decimal('2015')),
#  ('US-2014-144582           ', 'TC-21475                 ', 7, Decimal('2016')),
#  ('CA-2014-117513           ', 'BT-11395                 ', 7, Decimal('2016')),
#  ('CA-2014-118017           ', 'LC-16870                 ', 7, Decimal('2016')),
#  ('CA-2013-162747           ', 'AH-10030                 ', 7, Decimal('2015')),
#  ('CA-2012-132941           ', 'MM-18280                 ', 7, Decimal('2014')),
#  ('CA-2011-169726           ', 'JH-15985                 ', 7, Decimal('2013')),
#  ('CA-2011-150798           ', 'JK-15730                 ', 7, Decimal('2013')),
#  ('CA-2012-124919           ', 'SP-20650                 ', 7, Decimal('2014')),
#  ('CA-2012-109001           ', 'KN-16390                 ', 7, Decimal('2014')),
#  ('CA-2013-132143           ', 'FM-14215                 ', 7, Decimal('2015')),
#  ('US-2012-129007           ', 'KD-16615                 ', 7, Decimal('2014')),
#  ('CA-2012-118738           ', 'AG-10495                 ', 7, Decimal('2014')),
#  ('US-2012-160857           ', 'NW-18400                 ', 7, Decimal('2014')),
#  ('CA-2014-158120           ', 'KH-16330                 ', 7, Decimal('2016')),
#  ('CA-2014-131366           ', 'SC-20440                 ', 7, Decimal('2016')),
#  ('CA-2013-124590           ', 'SP-20920                 ', 7, Decimal('2015')),
#  ('CA-2013-142097           ', 'QJ-19255                 ', 7, Decimal('2015')),
#  ('CA-2014-102337           ', 'SD-20485                 ', 7, Decimal('2016')),
#  ('CA-2014-140515           ', 'GZ-14545                 ', 7, Decimal('2016')),
#  ('CA-2012-105627           ', 'DK-12895                 ', 7, Decimal('2014')),
#  ('CA-2014-158953           ', 'ML-18040                 ', 7, Decimal('2016')),
#  ('US-2013-167339           ', 'TD-20995                 ', 7, Decimal('2015')),
#  ('CA-2014-152695           ', 'CC-12220                 ', 7, Decimal('2016')),
#  ('CA-2011-102988           ', 'GM-14695                 ', 7, Decimal('2013')),
#  ('CA-2014-121503           ', 'FH-14275                 ', 7, Decimal('2016')),
#  ('CA-2012-150714           ', 'KH-16690                 ', 7, Decimal('2014')),
#  ('CA-2011-118192           ', 'MM-17920                 ', 7, Decimal('2013')),
#  ('CA-2013-118570           ', 'CC-12430                 ', 7, Decimal('2015')),
#  ('CA-2013-146374           ', 'HE-14800                 ', 7, Decimal('2015')),
#  ('CA-2013-163328           ', 'TP-21565                 ', 7, Decimal('2015')),
#  ('US-2011-131275           ', 'SC-20050                 ', 7, Decimal('2013')),
#  ('CA-2014-122056           ', 'PG-18895                 ', 7, Decimal('2016')),
#  ('US-2011-106992           ', 'SB-20290                 ', 7, Decimal('2013')),
#  ('CA-2012-103870           ', 'SP-20860                 ', 7, Decimal('2014')),
#  ('CA-2013-105207           ', 'BO-11350                 ', 7, Decimal('2015')),
#  ('US-2012-161991           ', 'SC-20725                 ', 7, Decimal('2014')),
#  ('CA-2012-140410           ', 'CM-12655                 ', 7, Decimal('2014')),
#  ('CA-2011-125731           ', 'CL-12565                 ', 7, Decimal('2013')),
#  ('CA-2012-111514           ', 'SC-20260                 ', 7, Decimal('2014')),
#  ('CA-2013-101651           ', 'SC-20305                 ', 7, Decimal('2015')),
#  ('CA-2012-110877           ', 'JE-15715                 ', 7, Decimal('2014')),
#  ('CA-2011-129938           ', 'EB-13705                 ', 7, Decimal('2013')),
#  ('CA-2013-167556           ', 'JM-15250                 ', 7, Decimal('2015')),
#  ('CA-2011-101392           ', 'AS-10630                 ', 7, Decimal('2013')),
#  ('CA-2011-102652           ', 'AY-10555                 ', 7, Decimal('2013')),
#  ('CA-2014-120376           ', 'TP-21130                 ', 7, Decimal('2016')),
#  ('CA-2014-158379           ', 'JA-15970                 ', 7, Decimal('2016')),
#  ('US-2012-113327           ', 'BF-11170                 ', 7, Decimal('2014')),
#  ('CA-2013-102092           ', 'PM-18940                 ', 7, Decimal('2015')),
#  ('CA-2014-140480           ', 'HE-14800                 ', 7, Decimal('2016')),
#  ('CA-2014-166128           ', 'LW-17215                 ', 7, Decimal('2016')),
#  ('CA-2014-149706           ', 'AS-10285                 ', 7, Decimal('2016')),
#  ('CA-2013-159765           ', 'TH-21100                 ', 7, Decimal('2015')),
#  ('CA-2013-147375           ', 'PO-19180                 ', 7, Decimal('2015')),
#  ('CA-2014-131695           ', 'RA-19285                 ', 7, Decimal('2016')),
#  ('CA-2013-125724           ', 'SM-20950                 ', 7, Decimal('2015')),
#  ('CA-2014-145653           ', 'CA-12775                 ', 7, Decimal('2016')),
#  ('CA-2014-147361           ', 'SB-20290                 ', 7, Decimal('2016')),
#  ('CA-2011-150329           ', 'SD-20485                 ', 7, Decimal('2013')),
#  ('CA-2013-128671           ', 'MT-18070                 ', 7, Decimal('2015')),
#  ('CA-2014-125913           ', 'JO-15145                 ', 7, Decimal('2016')),
#  ('US-2014-163300           ', 'ES-14020                 ', 7, Decimal('2016')),
#  ('CA-2012-132486           ', 'JF-15355                 ', 7, Decimal('2014')),
#  ('CA-2013-118052           ', 'BE-11455                 ', 7, Decimal('2015')),
#  ('CA-2014-163020           ', 'MO-17800                 ', 7, Decimal('2016')),
#  ('US-2014-165344           ', 'SB-20290                 ', 7, Decimal('2016')),
#  ('CA-2014-144862           ', 'EH-14005                 ', 7, Decimal('2016')),
#  ('CA-2011-165974           ', 'DL-12865                 ', 7, Decimal('2013')),
#  ('CA-2014-122763           ', 'HG-14845                 ', 7, Decimal('2016')),
#  ('CA-2014-112536           ', 'SG-20890                 ', 7, Decimal('2016')),
#  ('US-2012-126977           ', 'PF-19120                 ', 7, Decimal('2014')),
#  ('CA-2013-132479           ', 'MK-17905                 ', 7, Decimal('2015')),
#  ('CA-2012-147830           ', 'NF-18385                 ', 7, Decimal('2014')),
#  ('CA-2011-166191           ', 'DK-13150                 ', 7, Decimal('2013')),
#  ('CA-2011-128524           ', 'MZ-17515                 ', 7, Decimal('2013')),
#  ('CA-2012-109575           ', 'KH-16630                 ', 7, Decimal('2014')),
#  ('CA-2012-104129           ', 'ES-14080                 ', 7, Decimal('2014')),
#  ('US-2011-148194           ', 'BS-11365                 ', 7, Decimal('2013')),
#  ('CA-2011-119375           ', 'YC-21895                 ', 7, Decimal('2013')),
#  ('CA-2013-143924           ', 'SC-20680                 ', 7, Decimal('2015')),
#  ('CA-2013-168046           ', 'JD-15895                 ', 7, Decimal('2015')),
#  ('US-2014-162558           ', 'Dp-13240                 ', 7, Decimal('2016')),
#  ('CA-2011-131926           ', 'DW-13480                 ', 7, Decimal('2013')),
#  ('CA-2014-134649           ', 'CA-11965                 ', 7, Decimal('2016')),
#  ('CA-2014-140186           ', 'PG-18820                 ', 7, Decimal('2016')),
#  ('CA-2014-146024           ', 'SC-20770                 ', 7, Decimal('2016')),
#  ('CA-2012-149846           ', 'SB-20185                 ', 7, Decimal('2014')),
#  ('CA-2011-158771           ', 'SB-20290                 ', 7, Decimal('2013')),
#  ('US-2013-143819           ', 'KD-16270                 ', 7, Decimal('2015')),
#  ('CA-2012-122210           ', 'WB-21850                 ', 7, Decimal('2014')),
#  ('CA-2014-142636           ', 'KC-16675                 ', 7, Decimal('2016')),
#  ('CA-2012-160472           ', 'RK-19300                 ', 7, Decimal('2014')),
#  ('CA-2012-131856           ', 'JG-15160                 ', 7, Decimal('2014')),
#  ('CA-2013-141957           ', 'JG-15310                 ', 7, Decimal('2015')),
#  ('CA-2014-116204           ', 'VW-21775                 ', 7, Decimal('2016')),
#  ('CA-2014-133095           ', 'EH-14005                 ', 7, Decimal('2016')),
#  ('CA-2013-133697           ', 'CM-12445                 ', 7, Decimal('2015')),
#  ('CA-2014-150910           ', 'JL-15130                 ', 7, Decimal('2016')),
#  ('CA-2014-157483           ', 'EP-13915                 ', 7, Decimal('2016')),
#  ('CA-2014-164826           ', 'JF-15415                 ', 7, Decimal('2016')),
#  ('CA-2013-131289           ', 'SP-20620                 ', 7, Decimal('2015')),
#  ('CA-2011-130428           ', 'TG-21640                 ', 7, Decimal('2013')),
#  ('CA-2014-145233           ', 'DV-13465                 ', 7, Decimal('2016')),
#  ('CA-2014-155957           ', 'CC-12610                 ', 7, Decimal('2016')),
#  ('CA-2014-163335           ', 'AG-10675                 ', 7, Decimal('2016')),
#  ('US-2012-156496           ', 'WB-21850                 ', 7, Decimal('2014')),
#  ('CA-2013-140018           ', 'CK-12205                 ', 7, Decimal('2015')),
#  ('CA-2012-141327           ', 'LR-16915                 ', 7, Decimal('2014')),
#  ('CA-2011-123323           ', 'LH-16900                 ', 7, Decimal('2013')),
#  ('CA-2011-101560           ', 'CS-12250                 ', 7, Decimal('2013')),
#  ('CA-2013-135594           ', 'AH-10120                 ', 7, Decimal('2015')),
#  ('US-2014-159205           ', 'DB-12910                 ', 7, Decimal('2016')),
#  ('US-2013-131611           ', 'EP-13915                 ', 7, Decimal('2015')),
#  ('CA-2014-125199           ', 'HM-14860                 ', 7, Decimal('2016')),
#  ('CA-2014-121888           ', 'CL-11890                 ', 7, Decimal('2016')),
#  ('CA-2012-121776           ', 'RD-19585                 ', 7, Decimal('2014')),
#  ('CA-2012-149734           ', 'JC-16105                 ', 7, Decimal('2014')),
#  ('US-2014-107979           ', 'FO-14305                 ', 7, Decimal('2016')),
#  ('CA-2014-164756           ', 'SS-20140                 ', 7, Decimal('2016')),
#  ('CA-2013-159912           ', 'GB-14530                 ', 7, Decimal('2015')),
#  ('CA-2013-139010           ', 'MC-17635                 ', 7, Decimal('2015')),
#  ('CA-2013-155516           ', 'MK-17905                 ', 7, Decimal('2015')),
#  ('CA-2014-138975           ', 'SC-20380                 ', 7, Decimal('2016')),
#  ('CA-2014-138380           ', 'YS-21880                 ', 7, Decimal('2016')),
#  ('CA-2011-103702           ', 'AF-10885                 ', 7, Decimal('2013')),
#  ('CA-2012-140557           ', 'TN-21040                 ', 7, Decimal('2014')),
#  ('US-2013-123750           ', 'RB-19795                 ', 7, Decimal('2015')),
#  ('CA-2014-164112           ', 'ND-18460                 ', 7, Decimal('2016')),
#  ('CA-2013-137736           ', 'DC-13285                 ', 7, Decimal('2015')),
#  ('CA-2013-158568           ', 'RB-19465                 ', 7, Decimal('2015')),
#  ('US-2012-136427           ', 'JM-16195                 ', 7, Decimal('2014')),
#  ('CA-2013-153577           ', 'KH-16330                 ', 7, Decimal('2015')),
#  ('US-2014-124779           ', 'BF-11020                 ', 7, Decimal('2016')),
#  ('CA-2012-104948           ', 'KH-16510                 ', 7, Decimal('2014')),
#  ('CA-2014-117401           ', 'PP-18955                 ', 7, Decimal('2016')),
#  ('CA-2011-107755           ', 'CK-12760                 ', 7, Decimal('2013')),
#  ('CA-2013-132549           ', 'JK-15370                 ', 7, Decimal('2015')),
#  ('CA-2014-126956           ', 'GT-14710                 ', 7, Decimal('2016')),
#  ('CA-2012-144519           ', 'AW-10930                 ', 7, Decimal('2014')),
#  ('US-2012-150630           ', 'TB-21520                 ', 7, Decimal('2014')),
#  ('CA-2011-160262           ', 'TS-21205                 ', 7, Decimal('2013')),
#  ('CA-2012-148432           ', 'MC-18130                 ', 7, Decimal('2014')),
#  ('CA-2013-164938           ', 'PB-19210                 ', 7, Decimal('2015')),
#  ('CA-2014-139311           ', 'SF-20965                 ', 7, Decimal('2016')),
#  ('CA-2012-141810           ', 'BB-10990                 ', 7, Decimal('2014')),
#  ('CA-2013-160129           ', 'LS-17200                 ', 7, Decimal('2015')),
#  ('US-2013-139087           ', 'DK-13375                 ', 7, Decimal('2015')),
#  ('CA-2013-137330           ', 'KB-16585                 ', 7, Decimal('2015')),
#  ('CA-2013-114972           ', 'PF-19225                 ', 7, Decimal('2015')),
#  ('CA-2011-152443           ', 'FG-14260                 ', 7, Decimal('2013')),
#  ('CA-2014-150707           ', 'EL-13735                 ', 7, Decimal('2016')),
#  ('CA-2011-154599           ', 'KN-16450                 ', 7, Decimal('2013')),
#  ('CA-2013-124562           ', 'JP-16135                 ', 7, Decimal('2015')),
#  ('CA-2012-162537           ', 'RD-19585                 ', 7, Decimal('2014')),
#  ('CA-2014-166926           ', 'SO-20335                 ', 7, Decimal('2016')),
#  ('CA-2014-111591           ', 'PS-18970                 ', 7, Decimal('2016')),
#  ('US-2012-101399           ', 'JS-15940                 ', 7, Decimal('2014')),
#  ('CA-2012-142944           ', 'JL-15850                 ', 7, Decimal('2014')),
#  ('CA-2014-159352           ', 'KB-16585                 ', 7, Decimal('2016')),
#  ('CA-2013-126270           ', 'AF-10870                 ', 7, Decimal('2015')),
#  ('CA-2012-110548           ', 'AH-10690                 ', 7, Decimal('2014')),
#  ('US-2013-108455           ', 'MK-18160                 ', 7, Decimal('2015')),
#  ('CA-2013-114104           ', 'NP-18670                 ', 7, Decimal('2015')),
#  ('CA-2013-139395           ', 'MG-17650                 ', 7, Decimal('2015')),
#  ('CA-2014-122007           ', 'JK-15325                 ', 7, Decimal('2016')),
#  ('US-2012-164238           ', 'JW-15955                 ', 7, Decimal('2014')),
#  ('CA-2013-127761           ', 'SW-20275                 ', 7, Decimal('2015')),
#  ('US-2012-106873           ', 'KM-16720                 ', 7, Decimal('2014')),
#  ('CA-2012-108259           ', 'NS-18640                 ', 7, Decimal('2014')),
#  ('US-2011-160780           ', 'SV-20785                 ', 7, Decimal('2013')),
#  ('CA-2011-146843           ', 'PB-19150                 ', 7, Decimal('2013')),
#  ('US-2011-165659           ', 'LT-17110                 ', 7, Decimal('2013')),
#  ('CA-2013-134348           ', 'MS-17710                 ', 7, Decimal('2015')),
#  ('US-2012-101511           ', 'JE-15745                 ', 7, Decimal('2014')),
#  ('CA-2011-163223           ', 'KH-16690                 ', 7, Decimal('2013')),
#  ('CA-2011-144624           ', 'JM-15865                 ', 7, Decimal('2013')),
#  ('US-2014-160465           ', 'SW-20350                 ', 7, Decimal('2016')),
#  ('CA-2011-110065           ', 'SP-20650                 ', 7, Decimal('2013')),
#  ('US-2011-117744           ', 'MD-17860                 ', 7, Decimal('2013')),
#  ('US-2013-103674           ', 'AP-10720                 ', 7, Decimal('2015')),
#  ('CA-2013-156748           ', 'BS-11755                 ', 7, Decimal('2015')),
#  ('CA-2014-119809           ', 'YS-21880                 ', 7, Decimal('2016')),
#  ('CA-2012-157287           ', 'HR-14830                 ', 7, Decimal('2014')),
#  ('CA-2011-137351           ', 'DB-13615                 ', 7, Decimal('2013')),
#  ('CA-2014-111556           ', 'CD-11920                 ', 7, Decimal('2016')),
#  ('CA-2012-147788           ', 'TM-21010                 ', 7, Decimal('2014')),
#  ('CA-2014-140627           ', 'DK-12985                 ', 7, Decimal('2016')),
#  ('US-2011-123183           ', 'GR-14560                 ', 7, Decimal('2013')),
#  ('CA-2012-126725           ', 'BS-11665                 ', 7, Decimal('2014')),
#  ('US-2014-118087           ', 'SP-20620                 ', 7, Decimal('2016')),
#  ('US-2013-102232           ', 'MF-17665                 ', 7, Decimal('2015')),
#  ...]

# %%
#What is the Sales impact?

# %%
# %%sql SELECT EXTRACT(YEAR from Order_Date), Sales, round(cast(((profit/((sales-profit))*100))as numeric),2) as profit_percentage
# FROM store
# GROUP BY EXTRACT(YEAR from Order_Date), Sales, profit_percentage
# order by  profit_percentage
# limit 20
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 20 rows affected.
# [(Decimal('2014'), 143.128, Decimal('-73.33')),
#  (Decimal('2014'), 24.588, Decimal('-73.33')),
#  (Decimal('2016'), 1.624, Decimal('-73.33')),
#  (Decimal('2016'), 2.688, Decimal('-73.33')),
#  (Decimal('2016'), 1.556, Decimal('-72.97')),
#  (Decimal('2016'), 66.284, Decimal('-72.97')),
#  (Decimal('2016'), 1.392, Decimal('-72.97')),
#  (Decimal('2015'), 93.032, Decimal('-72.97')),
#  (Decimal('2015'), 26.406, Decimal('-72.97')),
#  (Decimal('2015'), 48.784, Decimal('-72.97')),
#  (Decimal('2016'), 73.176, Decimal('-72.97')),
#  (Decimal('2014'), 70.97, Decimal('-72.97')),
#  (Decimal('2014'), 19.568, Decimal('-72.97')),
#  (Decimal('2016'), 33.62, Decimal('-72.97')),
#  (Decimal('2015'), 2.334, Decimal('-72.97')),
#  (Decimal('2016'), 5.588, Decimal('-72.97')),
#  (Decimal('2013'), 3.16, Decimal('-72.97')),
#  (Decimal('2015'), 4.356, Decimal('-72.97')),
#  (Decimal('2015'), 62.79, Decimal('-72.60')),
#  (Decimal('2016'), 9.324, Decimal('-72.60'))]

# %%
#####################################

# %% [markdown]
# --Breakdown by Top vs Worst Sellers:

# %%
#Find Top 10 Categories (with the addition of best sub-category within the category).

# %%
# %%sql SELECT  Category, Sub_Category , round(cast(SUM(sales) as numeric),2) AS prod_sales
# FROM store
# GROUP BY Category,Sub_Category
# ORDER BY prod_sales DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 17 rows affected.
# [('Technology', 'Phones', Decimal('330007.05')),
#  ('Furniture', 'Chairs', Decimal('328449.10')),
#  ('Office Supplies', 'Storage', Decimal('223843.61')),
#  ('Furniture', 'Tables', Decimal('206965.53')),
#  ('Office Supplies', 'Binders', Decimal('203401.19')),
#  ('Technology', 'Machines', Decimal('189238.63')),
#  ('Technology', 'Accessories', Decimal('167380.32')),
#  ('Technology', 'Copiers', Decimal('149528.03')),
#  ('Furniture', 'Bookcases', Decimal('114880.00')),
#  ('Office Supplies', 'Appliances', Decimal('106152.99')),
#  ('Furniture', 'Furnishings', Decimal('91705.16')),
#  ('Office Supplies', 'Paper', Decimal('78479.21')),
#  ('Office Supplies', 'Supplies', Decimal('46673.54')),
#  ('Office Supplies', 'Art', Decimal('27118.79')),
#  ('Office Supplies', 'Envelopes', Decimal('16476.40')),
#  ('Office Supplies', 'Labels', Decimal('12486.31')),
#  ('Office Supplies', 'Fasteners', Decimal('3024.28'))]

# %%
#Find Top 10 Sub-Categories. :

# %%
# %%sql SELECT round(cast(SUM(sales) as numeric),2) AS prod_sales,Sub_Category
# FROM store
# GROUP BY Sub_Category
# ORDER BY prod_sales DESC
# OFFSET 1 ROWS FETCH NEXT 10 ROWS ONLY;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [(Decimal('328449.10'), 'Chairs'),
#  (Decimal('223843.61'), 'Storage'),
#  (Decimal('206965.53'), 'Tables'),
#  (Decimal('203401.19'), 'Binders'),
#  (Decimal('189238.63'), 'Machines'),
#  (Decimal('167380.32'), 'Accessories'),
#  (Decimal('149528.03'), 'Copiers'),
#  (Decimal('114880.00'), 'Bookcases'),
#  (Decimal('106152.99'), 'Appliances'),
#  (Decimal('91705.16'), 'Furnishings')]

# %%
#Find Worst 10 Categories.:

# %%
# %%sql SELECT round(cast(SUM(sales) as numeric),2) AS prod_sales, Category, Sub_Category
# FROM store
# GROUP BY Category, Sub_Category
# ORDER BY prod_sales;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 17 rows affected.
# [(Decimal('3024.28'), 'Office Supplies', 'Fasteners'),
#  (Decimal('12486.31'), 'Office Supplies', 'Labels'),
#  (Decimal('16476.40'), 'Office Supplies', 'Envelopes'),
#  (Decimal('27118.79'), 'Office Supplies', 'Art'),
#  (Decimal('46673.54'), 'Office Supplies', 'Supplies'),
#  (Decimal('78479.21'), 'Office Supplies', 'Paper'),
#  (Decimal('91705.16'), 'Furniture', 'Furnishings'),
#  (Decimal('106152.99'), 'Office Supplies', 'Appliances'),
#  (Decimal('114880.00'), 'Furniture', 'Bookcases'),
#  (Decimal('149528.03'), 'Technology', 'Copiers'),
#  (Decimal('167380.32'), 'Technology', 'Accessories'),
#  (Decimal('189238.63'), 'Technology', 'Machines'),
#  (Decimal('203401.19'), 'Office Supplies', 'Binders'),
#  (Decimal('206965.53'), 'Furniture', 'Tables'),
#  (Decimal('223843.61'), 'Office Supplies', 'Storage'),
#  (Decimal('328449.10'), 'Furniture', 'Chairs'),
#  (Decimal('330007.05'), 'Technology', 'Phones')]

# %%
#Find Worst 10 Sub-Categories. :

# %%
# %%sql SELECT round(cast(SUM(sales) as numeric),2) AS prod_sales, sub_Category
# FROM store
# GROUP BY Sub_Category
# ORDER BY prod_sales
# OFFSET 1 ROWS FETCH NEXT 10 ROWS ONLY;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [(Decimal('12486.31'), 'Labels'),
#  (Decimal('16476.40'), 'Envelopes'),
#  (Decimal('27118.79'), 'Art'),
#  (Decimal('46673.54'), 'Supplies'),
#  (Decimal('78479.21'), 'Paper'),
#  (Decimal('91705.16'), 'Furnishings'),
#  (Decimal('106152.99'), 'Appliances'),
#  (Decimal('114880.00'), 'Bookcases'),
#  (Decimal('149528.03'), 'Copiers'),
#  (Decimal('167380.32'), 'Accessories')]

# %%
#Show the Basic Order information.

# %%
# %%sql select count(Order_ID) as Purchases,
# round(cast(sum(Sales)as numeric),2) as Total_Sales,
# round(cast(sum(((profit/((sales-profit))*100)))/ count(*)as numeric),2) as avg_percentage_profit,
# min(Order_date) as first_purchase_date,
# max(Order_date) as Latest_purchase_date,
# count(distinct(Product_Name)) as Products_Purchased,
# count(distinct(City)) as Location_count
# from store
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [(9989, Decimal('2295810.15'), Decimal('32.38'), datetime.date(2013, 1, 3), datetime.date(2016, 12, 30), 1849, 531)]

# %%
###########################

# %% [markdown]
# # RETURN LEVEL ANALYSIS

# %%
#Find the number of returned orders.

# %%
# %%sql select Returned_items, count(Returned_items)as Returned_Items_Count
# from store
# group by Returned_items
# Having Returned_items='Returned'
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 1 rows affected.
# [('Returned', 800)]

# %%
#Find Top 10 Returned Categories.:

# %%
# %%sql SELECT Returned_items, Count(Returned_items) as no_of_returned ,Category, Sub_Category
# FROM store
# GROUP BY Returned_items,Category,Sub_Category
# Having Returned_items='Returned'
# ORDER BY count(Returned_items) DESC
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('Returned', 137, 'Office Supplies', 'Binders'),
#  ('Returned', 123, 'Office Supplies', 'Paper'),
#  ('Returned', 77, 'Technology', 'Phones'),
#  ('Returned', 72, 'Furniture', 'Furnishings'),
#  ('Returned', 61, 'Technology', 'Accessories'),
#  ('Returned', 57, 'Office Supplies', 'Storage'),
#  ('Returned', 53, 'Furniture', 'Chairs'),
#  ('Returned', 47, 'Office Supplies', 'Art'),
#  ('Returned', 40, 'Office Supplies', 'Appliances'),
#  ('Returned', 30, 'Furniture', 'Tables')]

# %%
#Find Top 10  Returned Sub-Categories.:

# %%
# %%sql SELECT Returned_items, Count(Returned_items),Sub_Category
# FROM store
# GROUP BY Returned_items, Sub_Category
# Having Returned_items='Returned'
# ORDER BY Count(Returned_items) DESC
# OFFSET 1 ROWS FETCH NEXT 10 ROWS ONLY;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('Returned', 123, 'Paper'),
#  ('Returned', 77, 'Phones'),
#  ('Returned', 72, 'Furnishings'),
#  ('Returned', 61, 'Accessories'),
#  ('Returned', 57, 'Storage'),
#  ('Returned', 53, 'Chairs'),
#  ('Returned', 47, 'Art'),
#  ('Returned', 40, 'Appliances'),
#  ('Returned', 30, 'Tables'),
#  ('Returned', 21, 'Labels')]

# %%
#Find Top 10 Customers Returned Frequently.:

# %%
# %%sql SELECT Returned_items, Count(Returned_items) As Returned_Items_Count, Customer_ID,Customer_duration, States,City
# FROM store
# GROUP BY Returned_items,customer_name, Customer_ID,customer_duration,states,city
# Having Returned_items='Returned'
# ORDER BY Count(Returned_items) DESC
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 10 rows affected.
# [('Returned', 14, 'SV-20365                 ', 'old customer', 'New York', 'New York City'),
#  ('Returned', 11, 'WB-21850                 ', 'old customer', 'California', 'Anaheim'),
#  ('Returned', 10, 'CL-12565                 ', 'old customer', 'California', 'Los Angeles'),
#  ('Returned', 9, 'SG-20080                 ', 'old customer', 'California', 'Redlands'),
#  ('Returned', 8, 'SP-20620                 ', 'old customer', 'Pennsylvania', 'Philadelphia'),
#  ('Returned', 8, 'DR-12880                 ', 'old customer', 'California', 'Inglewood'),
#  ('Returned', 8, 'RP-19390                 ', 'old customer', 'Washington', 'Seattle'),
#  ('Returned', 7, 'DH-13075                 ', 'old customer', 'California', 'Fairfield'),
#  ('Returned', 7, 'DM-13015                 ', 'old customer', 'New York', 'New York City'),
#  ('Returned', 7, 'RW-19540                 ', 'old customer', 'California', 'Brentwood')]

# %%
#Find Top 20 cities and states having higher return.

# %%
# %%sql SELECT Returned_items, Count(Returned_items)as Returned_Items_Count,States,City
# FROM store
# GROUP BY Returned_items,states,city
# Having Returned_items='Returned'
# ORDER BY Count(Returned_items) DESC
# limit 20;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 20 rows affected.
# [('Returned', 117, 'California', 'Los Angeles'),
#  ('Returned', 64, 'California', 'San Francisco'),
#  ('Returned', 60, 'Washington', 'Seattle'),
#  ('Returned', 45, 'New York', 'New York City'),
#  ('Returned', 18, 'California', 'San Diego'),
#  ('Returned', 16, 'Arizona', 'Phoenix'),
#  ('Returned', 13, 'Pennsylvania', 'Philadelphia'),
#  ('Returned', 12, 'Illinois', 'Chicago'),
#  ('Returned', 12, 'Oregon', 'Salem'),
#  ('Returned', 12, 'California', 'Brentwood'),
#  ('Returned', 11, 'California', 'Pasadena'),
#  ('Returned', 11, 'California', 'Anaheim'),
#  ('Returned', 10, 'California', 'Oakland'),
#  ('Returned', 9, 'California', 'Fairfield'),
#  ('Returned', 9, 'Texas', 'Houston'),
#  ('Returned', 9, 'Georgia', 'Columbus'),
#  ('Returned', 9, 'California', 'Redlands'),
#  ('Returned', 8, 'Delaware', 'Newark'),
#  ('Returned', 8, 'California', 'Inglewood'),
#  ('Returned', 8, 'Colorado', 'Denver')]

# %%
#Check whether new customers are returning higher or not.

# %%
# %%sql SELECT Returned_items, Count(Returned_items)as Returned_Items_Count,Customer_duration
# FROM store
# GROUP BY Returned_items,Customer_duration
# Having Returned_items='Returned'
# ORDER BY Count(Returned_items) DESC
# limit 20;
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 2 rows affected.
# [('Returned', 796, 'old customer'), ('Returned', 4, 'new customer')]

# %%
#Find Top  Reasons for returning.

# %%
# %%sql SELECT Returned_items, Count(Returned_items)as Returned_Items_Count,return_reason
# FROM store
# GROUP BY Returned_items,return_reason
# Having Returned_items='Returned'
# ORDER BY Count(Returned_items) DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/sql_analysis
# 6 rows affected.
# [('Returned', 304, 'Product Description Inaccurate'),
#  ('Returned', 158, 'Customer Dissatified With Product'),
#  ('Returned', 100, 'Product Arrived After Promised Delivery Date'),
#  ('Returned', 90, 'Product Damaged'),
#  ('Returned', 81, 'Product Ordered Accidently'),
#  ('Returned', 67, 'Incorrect Products Delivered')]
